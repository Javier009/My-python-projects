# %% [markdown]
# # Competitive analysis with SimilarWeb API
# Notes:
# 1) Top websites pero country are from the last momnthe avilable and seems that is not allowed to have them for aggregated time frames
# 2) Relevant sections of the API for this project: Top domains  per country, Total visits, Avg. session duration in Mobile and desktop (two different sections)
# 3) Data granularity: Country-->Monthly.
# 4) Data collected: For 50 countries, 6 selected websites, top 10 other websites (exlude adult websites): total visits, average session duration
#
# Data considerations:
# Data structures hits:
#     1) Granularity: Monthly, 49 countries since China is not avilable in SimilarWeb and also not very relevant for Google Busines
#     2) Timeframe: 2019-09 to 2022-09 --> 36 months
#     3) Top 10 + 8 websites of specified cohort for 49 countries = 49 hits
#     4) Total visits 18 websites * 50 countries = 882 hits
#     5) Desktop Average session duration * 50 countries = 882 hits
#     6) Mobile Average session duration * 50 countries = 882 hits
#     7) Total hits = 2695
#     8) Hits for testing = 300
#
# ## Data structures final tables shapes to be stored in csv files :
#
#     1) Granularity: Monthly, 49 countries since China is not avilable in SimilarWeb and also not very relevant for Google Busines
#     2) Timeframe: 2019-09 to 2022-09 --> 36 months
#     3) Total visits 17 websites * 50 * 36 months = 31752 rows
#     4) Average session duration 17 websites * 50 * 36 months = 29988 rows * 2 (Desktop and Mobile) =  63505 rows
#
# Process:
# Countries considereed:
#  1) From Google Ecosystem analysis extract top 50 countries, store them in a CSV file and upload it file to this notebook
#  2) Import SimilarWeb countries provided by the team in a CSV file
#  2.1) Modify Google top countries to match SimilarWeb string pattern to be modify at end stage
#  3) Verify that Google top 50 countries are avilable in SimilarWeb countries
# Websites considered:
#  1) Build a data structure (list, tuple whatever) with Websites present in each country no matter the ranking posisiton:
#
#      reddit.com
#      tiktok.com
#      instagram.com
#      facebook.com
#      amazon.com
#      youtube.com
#
#  2) Exlude Adult website from the analysis:
#      Build a list of XXX websites in the world to be exluded using Simi

# %% [markdown]
# ## Libraries imports

# %%
import requests
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Google countries to be reviewed in the SimilarWeb Api

# %% [markdown]
# ## API hits to extract top 10K adult websites worldwide that will be excluded from the analyses
# ### IMPORTANT: RUN every time that you need to do a full refresh of the data, otherwise extract topwebsites from the CVS file

# %% [markdown]
# ### Run this section once since data is stored in a excel file. Unless the month ended and we have 3000 hits again

# %%
#Adult web sites to be exluded ## TESTING to see if both geos criteria show same data BEFORE RUNNING API FOR TOP 100 PAGES

access_key = 'contact owner'
all_geos = ('world', 'worldwide')

adult_websites_api_path_one = f'https://api.similarweb.com/v1/website/$Adult/topsites/total?api_key={access_key}&start_date=2022-09&end_date=2022-09&country={all_geos[0]}&format=json&page=1'
adult_websites_api_path_two = f'https://api.similarweb.com/v1/website/$Adult/topsites/total?api_key={access_key}&start_date=2022-09&end_date=2022-09&country={all_geos[1]}&format=json&page=1'

adult_websites_api_path_option_one = requests.get(adult_websites_api_path_one).json()
adult_websites_api_path_option_two = requests.get(adult_websites_api_path_two).json()

# %%
all_geos = ('world', 'worldwide')
adult_websites_api_path_two = f'https://api.similarweb.com/v1/website/$Adult/topsites/total?api_key={access_key}&start_date=2022-09&end_date=2022-09&country={all_geos[1]}&format=json&page=1'
adult_websites_api_path_option_two = requests.get(adult_websites_api_path_two).json()

# %%
inconcistencies = []

if 'No data for requested country' in adult_websites_api_path_option_two['meta']['error_message']:
    print('OK! No data in option 2!')
else:
    for web_site_dict in  adult_websites_api_path_option_one['top_sites']:
        rank = web_site_dict['rank']
        domain_option_one = web_site_dict['domain']

        domain_option_two = [ w for w in [i for i in adult_websites_api_path_option_two['top_sites'] ] if w['rank'] == rank ][0]['domain']

        if domain_option_one == domain_option_two:
            pass
        else:
            inconcistencies.append((1 (domain_option_one, domain_option_two) )) 

    if len(inconcistencies) == 0:
        print('OK! Both sources are the same use option 1 or 2')
    else:
        print(f'Total inconcistencies = {sum([i[0] for i in inconcistencies])}')
        for inc in inconcistencies:
            print(inc[1])

# %%
adult_websites_api_path_option_two['meta']['error_message']

# %%
#Output from option 2 for double check, error_message should be recived

adult_websites_api_path_option_two

# %%
# Take a look if there is data in page 100 to see if it returns data
access_key = 'contact owner'
all_geos = ('world', 'worldwide')

adult_websites_api_path_page_100_test = f'https://api.similarweb.com/v1/website/$Adult/topsites/total?api_key={access_key}&start_date=2022-09&end_date=2022-09&country={all_geos[0]}&format=json&page=100'
adult_websites_api_path_page_100_test = requests.get(adult_websites_api_path_page_100_test).json()

# %%
adult_websites_api_path_page_100_test['top_sites'][0:10]

# %%
# RUN ONLY ONCE sice data will live in a csv file! 

# Run a loop to get all domains in 100 pages to exlude 10K top xxx websites in the world:  
access_key = 'contact owner'
all_geos = ('world', 'worldwide')

p_ranks =  []
p_domains = []

for page in range(1,100+1):
    adult_websites_api_path = f'https://api.similarweb.com/v1/website/$Adult/topsites/total?api_key={access_key}&start_date=2022-09&end_date=2022-09&country={all_geos[0]}&format=json&page={page}'
    adult_websites_api_data = requests.get(adult_websites_api_path).json()
    
    for web_site_dict in  adult_websites_api_data['top_sites']:
        
        rank = web_site_dict['rank']
        domain = web_site_dict['domain']
        
        p_ranks.append(rank)
        p_domains.append(domain)

# %%
len(p_ranks), len(p_domains)

# %%
#Create Adults websites data frame
#RUN ONLY ONCE SINCE DATA WILL BE STORED IN A CSV FILE AND AVED IN PLX TABLE

adults_web_sites = pd.DataFrame({'Rank': p_ranks,
                                 'Domain': p_domains})
adults_web_sites.head()

# %%
#Saving the data frame in a csv file that will be exported as plx table
#Use this data frame and not hit the API again until next month that we have 3000 hits again 
adults_web_sites.to_excel('Desktop/adult_websites.xlsx')

# %% [markdown]
# ## Load adult websites from Excel file. This websites will be exluded form anlaysis

# %%
adults_web_sites = pd.read_excel('adultwebsites_to_exlude.xlsx')
adults_web_sites
# Out:
#        Rank           Domain
# 0         1      xvideos.com
# 1         2      pornhub.com
# 2         3         xnxx.com
# 3         4     xhamster.com
# 4         5      realsrv.com
# ...     ...              ...
# 9995   9996  moro-douga.link
# 9996   9997      umechan.net
# 9997   9998       pimp61.net
# 9998   9999   baiselibre.com
# 9999  10000  sextingbook.com
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Run API hits for data collection
# ### Google countries mapped with SimilarWeb codes file upload and constant websites list definition

# %%
countries_data_frame = pd.read_excel('similarweb_countries.xlsx')
#Exlude China
countries_data_frame = countries_data_frame[countries_data_frame['country_code_lower_SW'] != 'Not in SW']
#Rank countries (They come sorted)
countries_data_frame['Search revenue rank'] = [i for i in range(1,50)]
countries_data_frame.head(), countries_data_frame.shape
# Out:
# (  country_code_google country_code_SW country_code_lower_SW  \
#  0                  US              US                    us
#  1                  GB              GB                    gb
#  2                  DE              DE                    de
#  3                  JP              JP                    jp
#  4                  NL              NL                    nl
#
#     Search revenue rank
#  0                    1
#  1                    2
#  2                    3
#  3                    4
#  4                    5  ,
#  (49, 4))

# %%
#Define how many countries we want to get data from the SW API
top_countries_to_get = 15
## Conutries that are not in the top 15 but we would like to have them
aditional_countries = ['mx', 'vn', 'kr']
final_countries_to_get = list(countries_data_frame[countries_data_frame['Search revenue rank'] <= top_countries_to_get]['country_code_lower_SW']) + aditional_countries
final_countries_to_get
# Out:
# ['us',
#  'gb',
#  'de',
#  'jp',
#  'nl',
#  'fr',
#  'ca',
#  'au',
#  'il',
#  'es',
#  'br',
#  'it',
#  'in',
#  'se',
#  'pl',
#  'mx',
#  'vn',
#  'kr']

# %% [markdown]
# ### Specify which domains you want to be present in all countries

# %%
#constant Webstie to be included  across countries
constant_web_sites =  ['google.com', 'youtube.com', 'facebook.com', 'amazon.com', 'wikipedia.com', 'twitter.com', 'instagram.com', 'reddit.com', 'pinterest.com', 'tiktok.com', 'spotify.com', 'twitch.com','netflix.com']

#constant_web_sites = ['amazon.com',
#                      'target.com',
#                      'walmart.com',
#                      'ebay.com',
#                      'shopify.com',
#                      'etsy.com',
#                      'craigslist.com',
#                      'nike.com' ,
#                      'bestbuy.com',
#                      'apple.com',
#                      'samsung.com',
#                      'homedepot.com']

constant_web_sites
# Out:
# ['google.com',
#  'youtube.com',
#  'facebook.com',
#  'amazon.com',
#  'wikipedia.com',
#  'twitter.com',
#  'instagram.com',
#  'reddit.com',
#  'pinterest.com',
#  'tiktok.com',
#  'spotify.com',
#  'twitch.com',
#  'netflix.com']

# %%
### Select at propetry level (RECOMMENDED) given that one propery could have more than 1 domain in SW API

selected_properties_cohort = ['google', 'youtube', 'facebook', 'amazon', 'wikipedia', 'twitter', 'instagram', 'reddit', 'pinterest', 'tiktok', 'spotify', 'twitch','netflix']

final_websites_to_get_from_properties = []

for prop_name in selected_properties_cohort:
    property_web_sites = [d['domain'] for d in top_websites_data_dicts if prop_name in d['domain'][0:d['domain'].index('.')] ]
    for d in property_web_sites:
        final_websites_to_get_from_properties.append(d)
final_websites_to_get_from_properties, len(final_websites_to_get_from_properties)
# Out:
# (['google.com',
#   'youtube.com',
#   'facebook.com',
#   'amazon.com',
#   'wikipedia.org',
#   'twitter.com',
#   'instagram.com',
#   'reddit.com',
#   'pinterest.com',
#   'tiktok.com',
#   'spotify.com',
#   'twitch.tv',
#   'netflix.com'],
#  13)

# %% [markdown]
# ## Define analyis parameters for selected cohorts

# %%
## Define if the analysis will focus only one a specific set of countries or in all selected markets  ## --> For all countries: countries_of_focus = [] 

countries_of_focus = ['us'] 

consider_cohort_counties = False

if consider_cohort_counties:
    api_countries_to_run = countries_of_focus
else:
    api_countries_to_run = final_countries_to_get

    
## DEFINE THE TYPE OF ANALYSIS TO BE DONE: Selected properties only OR include all top x websites defined in the variable threshold_top_domains
### False for all top x websites, True for selected cohort

selected_domains_cohort_only = False
property_level_aggregation = True ## To get all websites under that property name

# %%
selected_domains_cohort_only, property_level_aggregation, api_countries_to_run
# Out:
# (False,
#  True,
#  ['us',
#   'gb',
#   'de',
#   'jp',
#   'nl',
#   'fr',
#   'ca',
#   'au',
#   'il',
#   'es',
#   'br',
#   'it',
#   'in',
#   'se',
#   'pl',
#   'mx',
#   'vn',
#   'kr'])

# %%
#Number of domains per top country present in final_countries_to_get
threshold_top_domains = 40

#Variables definition for API data pulls

access_key = '9095e89d0b5649b0a1a7d2bb9c2c5816'
granularity = 'monthly'
t0_date = '2019-10'
t1_date = '2022-10'

#Adults websites to exlude from analysis
adult_domains_to_exlude = [adult_domain for adult_domain in adults_web_sites['Domain']]

#LISTS WHICH WILL POPULATE DATA FAMES:

## Desktop visits
desktop_visits_dates = []
desktop_visits_countries = []
desktop_visits_domains = []
desktop_visits_visits = [] 


## Mobile visits
mobile_visits_dates = []
mobile_visits_countries = []
mobile_visits_domains = []
mobile_visits_visits = [] 


## Desktop average session duration

desktop_visit_dur_dates = []
desktop_visit_dur_countries = []
desktop_visit_dur_domains = []
desktop_visit_dur_duration = [] 


## Mobile average session duration

mobile_visit_dur_dates = []
mobile_visit_dur_countries = []
mobile_visit_dur_domains = []
mobile_visit_dur_duration = [] 


for country_code in api_countries_to_run:
    
    if selected_domains_cohort_only == False and property_level_aggregation == False:  ## MOST HITS EXPENSIVE OPTION SINCE CONSIDERS all top x websites in all 15 most impotant geos
    
         #1) Get top domains data from the API for iterating country

        top_domains_path = f'https://api.similarweb.com/v1/website/$All/topsites/total?api_key={access_key}&start_date=2022-10&end_date=2022-10&country={country_code}&format=json&page=1'
        top_websites_data = requests.get(top_domains_path).json()
        top_websites_data_dicts = top_websites_data['top_sites']

        ## Extract domains and ranks and domains exlusion step

        country_domains_to_analyse = []

        for dic in top_websites_data_dicts:
            rank =  dic['rank']
            domain = dic['domain']
            country_domains_to_analyse.append([rank, domain])

            #exlude adult websites and constant websites from top websites cohort --> Constant WebSites will be added in later stage of this algorithm
            country_domains_to_analyse = [d for d in country_domains_to_analyse if d[1] not in adult_domains_to_exlude]
            country_domains_to_analyse = [d for d in country_domains_to_analyse if d[1] not in constant_web_sites]


        #3) Re rank websties avilable once adult and constant domains have been exluded        
        for n in range(0,len(country_domains_to_analyse)):
            country_domains_to_analyse[n].append(n)

        #Capture domain and new rank: Based on the new rank, grab only top x = threshold_top_domains domains
        country_domains_to_analyse = [d[1] for d in country_domains_to_analyse if d[2] <= threshold_top_domains]

        #4)Add constant websites across countries to the list to be analysed

        for constant_domain in constant_web_sites:
                country_domains_to_analyse.append(constant_domain)

        # Create a list from a set just to be sure that we are not duplicating domains

        country_domains_to_analyse = list(set(country_domains_to_analyse))
        
    elif selected_domains_cohort_only == True and property_level_aggregation == False:
        country_domains_to_analyse = constant_web_sites
        
    else:
         #1) Get domains under specific properties namesa from the API for iterating country

        top_domains_path = f'https://api.similarweb.com/v1/website/$All/topsites/total?api_key={access_key}&start_date=2022-10&end_date=2022-10&country={country_code}&format=json&page=1'
        top_websites_data = requests.get(top_domains_path).json()
        top_websites_data_dicts = top_websites_data['top_sites']
        
        country_domains_to_analyse = []

        for prop_name in selected_properties_cohort:
            property_web_sites = [d['domain'] for d in top_websites_data_dicts if prop_name in d['domain'][0:d['domain'].index('.')] ]
            for d in property_web_sites:
                country_domains_to_analyse.append(d)
        
        country_domains_to_analyse = list(set(country_domains_to_analyse + constant_web_sites))
    
                         
    #5) Extract Visits data for each website

    for domain in country_domains_to_analyse:

        # API DESKTOP visits calls       
        desktop_visits_path = f'https://api.similarweb.com/v1/website/{domain}/traffic-and-engagement/visits?api_key={access_key}&start_date={t0_date}&end_date={t1_date}&country={country_code}&granularity={granularity}&main_domain_only=false&format=json'
        desktop_visits_data = requests.get(desktop_visits_path).json()     
        desktop_visits_data_dicts = desktop_visits_data['visits'] 


        for date_visit in desktop_visits_data_dicts:
            date = date_visit['date']
            desktop_visits = int(date_visit['visits'])

            #Populating visits lists that will build total traffic data frame

            desktop_visits_dates.append(date)
            desktop_visits_countries.append(country_code)
            desktop_visits_domains.append(domain)
            desktop_visits_visits.append(desktop_visits)
            
        # API MOBILE visits calls       
        mobile_visits_path = f'https://api.similarweb.com/v2/website/{domain}/mobile-web/visits?api_key={access_key}&start_date={t0_date}&end_date={t1_date}&country={country_code}&granularity={granularity}&main_domain_only=false&format=json'
        mobile_visits_data = requests.get(mobile_visits_path).json()     
        mobile_visits_data_dicts = mobile_visits_data['visits'] 

        #Extract data from json structure to populate lists that will build total visits data frame

        for date_visit in mobile_visits_data_dicts:
            date = date_visit['date']
            mobile_visits = int(date_visit['visits'])

            #Populating visits lists that will build total traffic data frame

            mobile_visits_dates.append(date)
            mobile_visits_countries.append(country_code)
            mobile_visits_domains.append(domain)
            mobile_visits_visits.append(mobile_visits)
            
    #6) Extract average visit duration for Desktop

        #Desktop average visit duration API call
        desktop_average_visit_duration_path = f'https://api.similarweb.com/v1/website/{domain}/traffic-and-engagement/average-visit-duration?api_key={access_key}&start_date={t0_date}&end_date={t1_date}&country={country_code}&granularity={granularity}&main_domain_only=false&format=json&show_verified=false'
        desktop_average_visit_duration_data = requests.get(desktop_average_visit_duration_path).json()
        desktop_average_visit_duration_data_dicts = desktop_average_visit_duration_data['average_visit_duration']

        #Extract data from json structure to populate lists that will build total visits data frame

        for date_desk_session in desktop_average_visit_duration_data_dicts:
            date = date_desk_session['date']
            desk_average_visit_duration = date_desk_session['average_visit_duration']

            #Populating visits lists that will build total traffic data frame

            desktop_visit_dur_dates.append(date)
            desktop_visit_dur_countries.append(country_code)
            desktop_visit_dur_domains.append(domain)
            desktop_visit_dur_duration.append(desk_average_visit_duration)


    #7)Extract average visit duration for Mobile

         #Mobile average visit duration API call
        mobile_average_visit_duration_path = f'https://api.similarweb.com/v2/website/{domain}/mobile-web/average-visit-duration?api_key={access_key}&start_date={t0_date}&end_date={t1_date}&country={country_code}&granularity={granularity}&main_domain_only=false&format=json'
        mobile_average_visit_duration_data = requests.get(mobile_average_visit_duration_path).json()
        mobile_average_visit_duration_data_dicts = mobile_average_visit_duration_data['average_visit_duration']

        for date_mobile_session in mobile_average_visit_duration_data_dicts:
            date = date_mobile_session['date']
            mobile_average_visit_duration = date_mobile_session['average_visit_duration']

            #Populating visits lists that will build total traffic data frame

            mobile_visit_dur_dates.append(date)
            mobile_visit_dur_countries.append(country_code)
            mobile_visit_dur_domains.append(domain)
            mobile_visit_dur_duration.append(mobile_average_visit_duration)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [122], in <cell line: 46>()
#      92 top_domains_path = f'https://api.similarweb.com/v1/website/$All/topsites/total?api_key={access_key}&start_date=2022-10&end_date=2022-10&country={country_code}&format=json&page=1'
#      93 top_websites_data = requests.get(top_domains_path).json()
# ---> 94 top_websites_data_dicts = top_websites_data['top_sites']
#      96 country_domains_to_analyse = []
#      98 for prop_name in selected_properties_cohort:
#
# KeyError: 'top_sites'

# %%
## desktop visits
len(desktop_visits_dates), len(desktop_visits_countries), len(desktop_visits_domains ), len(desktop_visits_visits )
# Out:
# (10915, 10915, 10915, 10915)

# %%
## Mobile visits
len(mobile_visits_dates), len(mobile_visits_countries), len(mobile_visits_domains ), len(mobile_visits_visits )
# Out:
# (10915, 10915, 10915, 10915)

# %%
## Desktop average session duration
len(desktop_visit_dur_dates ), len(desktop_visit_dur_countries ), len(desktop_visit_dur_domains ), len(desktop_visit_dur_duration)
# Out:
# (10915, 10915, 10915, 10915)

# %%
## Mobile average session duration

len(mobile_visit_dur_dates), len(mobile_visit_dur_countries), len(mobile_visit_dur_domains), len(mobile_visit_dur_duration)
# Out:
# (10915, 10915, 10915, 10915)

# %% [markdown]
# ## Data Frames creation and export to Excel/CSV files

# %%
# Desktop visits data frame

desktop_total_visits_df = pd.DataFrame({'Date':desktop_visits_dates,
                                        'Country Code': desktop_visits_countries,
                                        'Domain': desktop_visits_domains,
                                        'Visits':desktop_visits_visits })

desktop_total_visits_df['form_factor'] = 'Desktop Browser'


#Mobile visits data frame


mobile_total_visits_df = pd.DataFrame({'Date':mobile_visits_dates,
                                       'Country Code': mobile_visits_countries,
                                       'Domain': mobile_visits_domains,
                                       'Visits':mobile_visits_visits })

mobile_total_visits_df['form_factor'] = 'Mobile Browser'


total_visits_df = pd.concat([desktop_total_visits_df,mobile_total_visits_df])


#Avg Session Duration Desktop

desktop_avg_visit_duration_df = pd.DataFrame({'Date':desktop_visit_dur_dates,
                                              'Country Code': desktop_visit_dur_countries,
                                              'Domain': desktop_visit_dur_domains,
                                              'Avg. visit duration (sec)':desktop_visit_dur_duration })

desktop_avg_visit_duration_df['form_factor'] = 'Desktop Browser'



## Mobile average session duration


mobile_avg_visit_duration_df = pd.DataFrame({'Date':mobile_visit_dur_dates,
                                              'Country Code': mobile_visit_dur_countries,
                                              'Domain': mobile_visit_dur_domains,
                                              'Avg. visit duration (sec)':mobile_visit_dur_duration })


mobile_avg_visit_duration_df['form_factor'] = 'Mobile Browser'


avg_visit_duration_df = pd.concat([desktop_avg_visit_duration_df,mobile_avg_visit_duration_df])

# %%
total_visits_df
# Out:
#              Date Country Code         Domain    Visits      form_factor
# 0      2019-10-01           us     twitch.com     14184  Desktop Browser
# 1      2019-11-01           us     twitch.com     13230  Desktop Browser
# 2      2019-12-01           us     twitch.com      9922  Desktop Browser
# 3      2020-01-01           us     twitch.com     13238  Desktop Browser
# 4      2020-02-01           us     twitch.com     10298  Desktop Browser
# ...           ...          ...            ...       ...              ...
# 10910  2022-06-01           vn  wikipedia.org  22919217   Mobile Browser
# 10911  2022-07-01           vn  wikipedia.org  22541367   Mobile Browser
# 10912  2022-08-01           vn  wikipedia.org  22963854   Mobile Browser
# 10913  2022-09-01           vn  wikipedia.org  23031662   Mobile Browser
# 10914  2022-10-01           vn  wikipedia.org  23031311   Mobile Browser
#
# [21830 rows x 5 columns]

# %%
avg_visit_duration_df
# Out:
#              Date Country Code         Domain  Avg. visit duration (sec)  \
# 0      2019-10-01           us     twitch.com                 311.444207
# 1      2019-11-01           us     twitch.com                 536.613463
# 2      2019-12-01           us     twitch.com                 141.209495
# 3      2020-01-01           us     twitch.com                 290.834538
# 4      2020-02-01           us     twitch.com                 255.233536
# ...           ...          ...            ...                        ...
# 10910  2022-06-01           vn  wikipedia.org                 182.958655
# 10911  2022-07-01           vn  wikipedia.org                 186.047436
# 10912  2022-08-01           vn  wikipedia.org                 181.318946
# 10913  2022-09-01           vn  wikipedia.org                 182.443149
# 10914  2022-10-01           vn  wikipedia.org                 184.670358
#
#            form_factor
# 0      Desktop Browser
# 1      Desktop Browser
# 2      Desktop Browser
# 3      Desktop Browser
# 4      Desktop Browser
# ...                ...
# 10910   Mobile Browser
# 10911   Mobile Browser
# 10912   Mobile Browser
# 10913   Mobile Browser
# 10914   Mobile Browser
#
# [21830 rows x 5 columns]

# %%
#Making some checks on visits
country_to_check = 'jp'
total_visits_df[total_visits_df['Country Code'] == country_to_check]['Domain'].unique(), len(total_visits_df[total_visits_df['Country Code'] == country_to_check]['Domain'].unique())
# Out:
# (array(['google.co.jp', 'twitch.com', 'spotify.com', 'reddit.com',
#         'twitter.com', 'wikipedia.com', 'google.com', 'youtube.com',
#         'facebook.com', 'amazon.co.jp', 'pinterest.com', 'netflix.com',
#         'amazon.com', 'tiktok.com', 'instagram.com', 'wikipedia.org'],
#        dtype=object),
#  16)

# %%
#Making some checks on avg session duration
avg_visit_duration_df[avg_visit_duration_df['Country Code'] == country_to_check]['Domain'].unique(), len(avg_visit_duration_df[avg_visit_duration_df['Country Code'] == country_to_check]['Domain'].unique())
# Out:
# (array(['google.co.jp', 'twitch.com', 'spotify.com', 'reddit.com',
#         'twitter.com', 'wikipedia.com', 'google.com', 'youtube.com',
#         'facebook.com', 'amazon.co.jp', 'pinterest.com', 'netflix.com',
#         'amazon.com', 'tiktok.com', 'instagram.com', 'wikipedia.org'],
#        dtype=object),
#  16)

# %% [markdown]
# ## Saving data in xlsx files to be uploaded to plx

# %%
#Saving data in excel/csv files
#Saving the data frame in a csv file that will be exported as plx table
#Use this data frame and not hit the API again until next month that we have 3000 hits again 

visits_file_name = 'sw_total_visits_traffic_selected_properties_monthly.xlsx'
session_duration_file_name = 'sw_avg_visit_duation_selected_properties_monthly.xlsx'

total_visits_df.to_excel(f'Documents/{visits_file_name}')
avg_visit_duration_df.to_excel(f'Documents/{session_duration_file_name}')

# %%
list(set([1,2,3] + [3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
access_key = '9095e89d0b5649b0a1a7d2bb9c2c5816'
granularity = 'daily'
t0_date = '2019-10'
t1_date = '2022-10'
domain = 'pinterest.fr'

desktop_average_visit_duration_path = f'https://api.similarweb.com/v1/website/{domain}/traffic-and-engagement/average-visit-duration?api_key={access_key}&start_date={t0_date}&end_date={t1_date}&country={country_code}&granularity={granularity}&main_domain_only=false&format=json&show_verified=false'
desktop_average_visit_duration_data = requests.get(desktop_average_visit_duration_path).json()
desktop_average_visit_duration_data_dicts = desktop_average_visit_duration_data['average_visit_duration']
desktop_average_visit_duration_data_dicts
# Out:
# [{'date': '2019-10-01', 'average_visit_duration': 210.39816103982406},
#  {'date': '2019-10-02', 'average_visit_duration': 269.44583799132903},
#  {'date': '2019-10-03', 'average_visit_duration': 232.34135954095015},
#  {'date': '2019-10-04', 'average_visit_duration': 315.3708825835477},
#  {'date': '2019-10-05', 'average_visit_duration': 146.40128671174728},
#  {'date': '2019-10-06', 'average_visit_duration': 274.4054460087132},
#  {'date': '2019-10-07', 'average_visit_duration': 375.4153862337986},
#  {'date': '2019-10-08', 'average_visit_duration': 455.1045975239784},
#  {'date': '2019-10-09', 'average_visit_duration': 333.68924263199307},
#  {'date': '2019-10-10', 'average_visit_duration': 469.9454046655952},
#  {'date': '2019-10-11', 'average_visit_duration': 326.95624185406484},
#  {'date': '2019-10-12', 'average_visit_duration': 221.8645681554739},
#  {'date': '2019-10-13', 'average_visit_duration': 458.98549567142186},
#  {'date': '2019-10-14', 'average_visit_duration': 283.353437520667},
#  {'date': '2019-10-15', 'average_visit_duration': 104.47372727309985},
#  {'date': '2019-10-16', 'average_visit_duration': 277.6443894876777},
#  {'date': '2019-10-17', 'average_visit_duration': 146.06443861613602},
#  {'date': '2019-10-18', 'average_visit_duration': 326.95624185406484},
#  {'date': '2019-10-19', 'average_visit_duration': 221.8645681554739},
#  {'date': '2019-10-20', 'average_visit_duration': 458.98549567142186},
#  {'date': '2019-10-21', 'average_visit_duration': 283.353437520667},
#  {'date': '2019-10-22', 'average_visit_duration': 104.47372727309985},
#  {'date': '2019-10-23', 'average_visit_duration': 333.68924263199307},
#  {'date': '2019-10-24', 'average_visit_duration': 469.9454046655952},
#  {'date': '2019-10-25', 'average_visit_duration': 326.95624185406484},
#  {'date': '2019-10-26', 'average_visit_duration': 221.8645681554739},
#  {'date': '2019-10-27', 'average_visit_duration': 380.5880629699276},
#  {'date': '2019-10-28', 'average_visit_duration': 372.2022953222527},
#  {'date': '2019-10-29', 'average_visit_duration': 362.5721929836466},
#  {'date': '2019-10-30', 'average_visit_duration': 355.20785326887625},
#  {'date': '2019-10-31', 'average_visit_duration': 391.4346096261646},
#  {'date': '2019-11-01', 'average_visit_duration': 362.3178911715437},
#  {'date': '2019-11-02', 'average_visit_duration': 307.2104583469771},
#  {'date': '2019-11-03', 'average_visit_duration': 240.9837358688232},
#  {'date': '2019-11-04', 'average_visit_duration': 250.6883473925147},
#  {'date': '2019-11-05', 'average_visit_duration': 640.9420569261672},
#  {'date': '2019-11-06', 'average_visit_duration': 311.6496795911086},
#  {'date': '2019-11-07', 'average_visit_duration': 249.20700017184495},
#  {'date': '2019-11-08', 'average_visit_duration': 184.24378825271629},
#  {'date': '2019-11-09', 'average_visit_duration': 400.7850409484343},
#  {'date': '2019-11-10', 'average_visit_duration': 358.34194964657496},
#  {'date': '2019-11-11', 'average_visit_duration': 364.52986175200044},
#  {'date': '2019-11-12', 'average_visit_duration': 665.0816060131804},
#  {'date': '2019-11-13', 'average_visit_duration': 497.23721276591743},
#  {'date': '2019-11-14', 'average_visit_duration': 368.4749969799174},
#  {'date': '2019-11-15', 'average_visit_duration': 353.79726630236183},
#  {'date': '2019-11-16', 'average_visit_duration': 97.11290049004062},
#  {'date': '2019-11-17', 'average_visit_duration': 352.26993450503403},
#  {'date': '2019-11-18', 'average_visit_duration': 423.53385468915565},
#  {'date': '2019-11-19', 'average_visit_duration': 299.56523102442037},
#  {'date': '2019-11-20', 'average_visit_duration': 364.0260822812056},
#  {'date': '2019-11-21', 'average_visit_duration': 209.23902952685683},
#  {'date': '2019-11-22', 'average_visit_duration': 216.69928270797888},
#  {'date': '2019-11-23', 'average_visit_duration': 552.3646902405173},
#  {'date': '2019-11-24', 'average_visit_duration': 266.79111176885635},
#  {'date': '2019-11-25', 'average_visit_duration': 361.4015254195881},
#  {'date': '2019-11-26', 'average_visit_duration': 332.3200401316181},
#  {'date': '2019-11-27', 'average_visit_duration': 304.31673070155244},
#  {'date': '2019-11-28', 'average_visit_duration': 236.93405636435457},
#  {'date': '2019-11-29', 'average_visit_duration': 146.40274242088051},
#  {'date': '2019-11-30', 'average_visit_duration': 328.1490659232532},
#  {'date': '2019-12-01', 'average_visit_duration': 261.4151559774542},
#  {'date': '2019-12-02', 'average_visit_duration': 309.4079160925672},
#  {'date': '2019-12-03', 'average_visit_duration': 358.9604743301543},
#  {'date': '2019-12-04', 'average_visit_duration': 386.0675572356885},
#  {'date': '2019-12-05', 'average_visit_duration': 395.7969860416161},
#  {'date': '2019-12-06', 'average_visit_duration': 379.418085247757},
#  {'date': '2019-12-07', 'average_visit_duration': 281.69659890537304},
#  {'date': '2019-12-08', 'average_visit_duration': 278.79481385215547},
#  {'date': '2019-12-09', 'average_visit_duration': 227.87694090164467},
#  {'date': '2019-12-10', 'average_visit_duration': 287.1526263485889},
#  {'date': '2019-12-11', 'average_visit_duration': 188.03220815994354},
#  {'date': '2019-12-12', 'average_visit_duration': 423.399550193254},
#  {'date': '2019-12-13', 'average_visit_duration': 213.15160827454238},
#  {'date': '2019-12-14', 'average_visit_duration': 176.59334830226098},
#  {'date': '2019-12-15', 'average_visit_duration': 285.1031771512815},
#  {'date': '2019-12-16', 'average_visit_duration': 242.9829168379614},
#  {'date': '2019-12-17', 'average_visit_duration': 166.87581266583393},
#  {'date': '2019-12-18', 'average_visit_duration': 159.48532359660905},
#  {'date': '2019-12-19', 'average_visit_duration': 210.1218700723294},
#  {'date': '2019-12-20', 'average_visit_duration': 230.67685832612742},
#  {'date': '2019-12-21', 'average_visit_duration': 241.65997249780344},
#  {'date': '2019-12-22', 'average_visit_duration': 462.1282314140392},
#  {'date': '2019-12-23', 'average_visit_duration': 361.5627593671179},
#  {'date': '2019-12-24', 'average_visit_duration': 69.63062050403327},
#  {'date': '2019-12-25', 'average_visit_duration': 312.1397761105546},
#  {'date': '2019-12-26', 'average_visit_duration': 187.92733266525738},
#  {'date': '2019-12-27', 'average_visit_duration': 290.5742466206883},
#  {'date': '2019-12-28', 'average_visit_duration': 435.3804459773145},
#  {'date': '2019-12-29', 'average_visit_duration': 448.3525396210642},
#  {'date': '2019-12-30', 'average_visit_duration': 393.95025399303006},
#  {'date': '2019-12-31', 'average_visit_duration': 286.10970420550365},
#  {'date': '2020-01-01', 'average_visit_duration': 477.67190435912164},
#  {'date': '2020-01-02', 'average_visit_duration': 326.527487356481},
#  {'date': '2020-01-03', 'average_visit_duration': 574.7273875576365},
#  {'date': '2020-01-04', 'average_visit_duration': 497.69768535863744},
#  {'date': '2020-01-05', 'average_visit_duration': 355.6602141358559},
#  {'date': '2020-01-06', 'average_visit_duration': 148.90647546165823},
#  {'date': '2020-01-07', 'average_visit_duration': 497.5055207647079},
#  {'date': '2020-01-08', 'average_visit_duration': 368.2758180440796},
#  {'date': '2020-01-09', 'average_visit_duration': 190.90479290859827},
#  {'date': '2020-01-10', 'average_visit_duration': 122.48201277102741},
#  {'date': '2020-01-11', 'average_visit_duration': 309.2708764658423},
#  {'date': '2020-01-12', 'average_visit_duration': 287.83800003054137},
#  {'date': '2020-01-13', 'average_visit_duration': 198.04357207365115},
#  {'date': '2020-01-14', 'average_visit_duration': 248.5400953036836},
#  {'date': '2020-01-15', 'average_visit_duration': 211.37026236725106},
#  {'date': '2020-01-16', 'average_visit_duration': 309.09120032355975},
#  {'date': '2020-01-17', 'average_visit_duration': 302.54886019813665},
#  {'date': '2020-01-18', 'average_visit_duration': 274.30026021298755},
#  {'date': '2020-01-19', 'average_visit_duration': 299.1294336623365},
#  {'date': '2020-01-20', 'average_visit_duration': 256.5563285380393},
#  {'date': '2020-01-21', 'average_visit_duration': 215.46345375263684},
#  {'date': '2020-01-22', 'average_visit_duration': 194.32637554904403},
#  {'date': '2020-01-23', 'average_visit_duration': 239.76546540440665},
#  {'date': '2020-01-24', 'average_visit_duration': 110.1761399441297},
#  {'date': '2020-01-25', 'average_visit_duration': 138.188147139915},
#  {'date': '2020-01-26', 'average_visit_duration': 243.96227894543645},
#  {'date': '2020-01-27', 'average_visit_duration': 172.47837881313347},
#  {'date': '2020-01-28', 'average_visit_duration': 389.81890041259555},
#  {'date': '2020-01-29', 'average_visit_duration': 343.6045940778983},
#  {'date': '2020-01-30', 'average_visit_duration': 340.9596120376692},
#  {'date': '2020-01-31', 'average_visit_duration': 311.7804185575152},
#  {'date': '2020-02-01', 'average_visit_duration': 335.7119797672657},
#  {'date': '2020-02-02', 'average_visit_duration': 313.8095308444923},
#  {'date': '2020-02-03', 'average_visit_duration': 366.5161318992975},
#  {'date': '2020-02-04', 'average_visit_duration': 288.93579887934237},
#  {'date': '2020-02-05', 'average_visit_duration': 131.55176311027213},
#  {'date': '2020-02-06', 'average_visit_duration': 228.600228871327},
#  {'date': '2020-02-07', 'average_visit_duration': 315.20050832502216},
#  {'date': '2020-02-08', 'average_visit_duration': 316.04205468649906},
#  {'date': '2020-02-09', 'average_visit_duration': 365.89376825149225},
#  {'date': '2020-02-10', 'average_visit_duration': 366.5161318992975},
#  {'date': '2020-02-11', 'average_visit_duration': 288.93579887934237},
#  {'date': '2020-02-12', 'average_visit_duration': 192.4528846890737},
#  {'date': '2020-02-13', 'average_visit_duration': 233.40768743906088},
#  {'date': '2020-02-14', 'average_visit_duration': 163.29811152681012},
#  {'date': '2020-02-15', 'average_visit_duration': 250.32194568842766},
#  {'date': '2020-02-16', 'average_visit_duration': 198.88513508578},
#  {'date': '2020-02-17', 'average_visit_duration': 250.8402491628774},
#  {'date': '2020-02-18', 'average_visit_duration': 137.47266042695284},
#  {'date': '2020-02-19', 'average_visit_duration': 262.65102845492476},
#  {'date': '2020-02-20', 'average_visit_duration': 420.4885509832469},
#  {'date': '2020-02-21', 'average_visit_duration': 345.3306413993279},
#  {'date': '2020-02-22', 'average_visit_duration': 362.2236581400456},
#  {'date': '2020-02-23', 'average_visit_duration': 169.87938930594984},
#  {'date': '2020-02-24', 'average_visit_duration': 281.1143985127225},
#  {'date': '2020-02-25', 'average_visit_duration': 186.36688004161485},
#  {'date': '2020-02-26', 'average_visit_duration': 254.65449874047846},
#  {'date': '2020-02-27', 'average_visit_duration': 164.13429892721592},
#  {'date': '2020-02-28', 'average_visit_duration': 315.3475093814857},
#  {'date': '2020-02-29', 'average_visit_duration': 193.8499140546674},
#  {'date': '2020-03-01', 'average_visit_duration': 163.20901379343528},
#  {'date': '2020-03-02', 'average_visit_duration': 150.09485000651517},
#  {'date': '2020-03-03', 'average_visit_duration': 231.83288583610283},
#  {'date': '2020-03-04', 'average_visit_duration': 354.0150775235536},
#  {'date': '2020-03-05', 'average_visit_duration': 135.87074144210587},
#  {'date': '2020-03-06', 'average_visit_duration': 194.47221686874138},
#  {'date': '2020-03-07', 'average_visit_duration': 199.13154748665485},
#  {'date': '2020-03-08', 'average_visit_duration': 211.52412920901662},
#  {'date': '2020-03-09', 'average_visit_duration': 279.4264864588188},
#  {'date': '2020-03-10', 'average_visit_duration': 272.905585534775},
#  {'date': '2020-03-11', 'average_visit_duration': 172.11692908504503},
#  {'date': '2020-03-12', 'average_visit_duration': 161.041669284862},
#  {'date': '2020-03-13', 'average_visit_duration': 98.08313749096824},
#  {'date': '2020-03-14', 'average_visit_duration': 194.44754626613},
#  {'date': '2020-03-15', 'average_visit_duration': 96.79676765870279},
#  {'date': '2020-03-16', 'average_visit_duration': 328.54588403072455},
#  {'date': '2020-03-17', 'average_visit_duration': 275.00280067462364},
#  {'date': '2020-03-18', 'average_visit_duration': 171.26721819702428},
#  {'date': '2020-03-19', 'average_visit_duration': 401.82602219382886},
#  {'date': '2020-03-20', 'average_visit_duration': 310.72825193724833},
#  {'date': '2020-03-21', 'average_visit_duration': 166.8963727236606},
#  {'date': '2020-03-22', 'average_visit_duration': 309.54806778035106},
#  {'date': '2020-03-23', 'average_visit_duration': 305.3491129844197},
#  {'date': '2020-03-24', 'average_visit_duration': 157.81301480716155},
#  {'date': '2020-03-25', 'average_visit_duration': 246.96672883315765},
#  {'date': '2020-03-26', 'average_visit_duration': 305.6525929996016},
#  {'date': '2020-03-27', 'average_visit_duration': 165.4178297372323},
#  {'date': '2020-03-28', 'average_visit_duration': 293.22232752650166},
#  {'date': '2020-03-29', 'average_visit_duration': 486.2213788268712},
#  {'date': '2020-03-30', 'average_visit_duration': 425.5015159045104},
#  {'date': '2020-03-31', 'average_visit_duration': 252.99468610456773},
#  {'date': '2020-04-01', 'average_visit_duration': 229.17822374630163},
#  {'date': '2020-04-02', 'average_visit_duration': 275.7808666163725},
#  {'date': '2020-04-03', 'average_visit_duration': 223.94339696787114},
#  {'date': '2020-04-04', 'average_visit_duration': 195.8217663601553},
#  {'date': '2020-04-05', 'average_visit_duration': 237.95908671025765},
#  {'date': '2020-04-06', 'average_visit_duration': 201.6453910781263},
#  {'date': '2020-04-07', 'average_visit_duration': 232.64206940067766},
#  {'date': '2020-04-08', 'average_visit_duration': 291.18684882201353},
#  {'date': '2020-04-09', 'average_visit_duration': 188.8069696269506},
#  {'date': '2020-04-10', 'average_visit_duration': 297.9015110657836},
#  {'date': '2020-04-11', 'average_visit_duration': 159.73030343746126},
#  {'date': '2020-04-12', 'average_visit_duration': 281.0121101904559},
#  {'date': '2020-04-13', 'average_visit_duration': 278.6538320626413},
#  {'date': '2020-04-14', 'average_visit_duration': 269.04611572879094},
#  {'date': '2020-04-15', 'average_visit_duration': 221.566509886712},
#  {'date': '2020-04-16', 'average_visit_duration': 200.9791689230317},
#  {'date': '2020-04-17', 'average_visit_duration': 215.66625193783298},
#  {'date': '2020-04-18', 'average_visit_duration': 256.479049068701},
#  {'date': '2020-04-19', 'average_visit_duration': 268.20539647867406},
#  {'date': '2020-04-20', 'average_visit_duration': 224.8980970157891},
#  {'date': '2020-04-21', 'average_visit_duration': 287.56884072692634},
#  {'date': '2020-04-22', 'average_visit_duration': 264.1215701910716},
#  {'date': '2020-04-23', 'average_visit_duration': 146.89797776154967},
#  {'date': '2020-04-24', 'average_visit_duration': 307.20359675632784},
#  {'date': '2020-04-25', 'average_visit_duration': 172.88096261993425},
#  {'date': '2020-04-26', 'average_visit_duration': 215.5487214585561},
#  {'date': '2020-04-27', 'average_visit_duration': 191.7192571861046},
#  {'date': '2020-04-28', 'average_visit_duration': 373.13218873910495},
#  {'date': '2020-04-29', 'average_visit_duration': 147.21145313052943},
#  {'date': '2020-04-30', 'average_visit_duration': 248.0503172777539},
#  {'date': '2020-05-01', 'average_visit_duration': 230.9314087790986},
#  {'date': '2020-05-02', 'average_visit_duration': 259.6722666005141},
#  {'date': '2020-05-03', 'average_visit_duration': 220.01672525708932},
#  {'date': '2020-05-04', 'average_visit_duration': 111.60550665606219},
#  {'date': '2020-05-05', 'average_visit_duration': 206.4220033572539},
#  {'date': '2020-05-06', 'average_visit_duration': 210.75248314531234},
#  {'date': '2020-05-07', 'average_visit_duration': 252.69637176517696},
#  {'date': '2020-05-08', 'average_visit_duration': 194.92429009524628},
#  {'date': '2020-05-09', 'average_visit_duration': 226.4034335949377},
#  {'date': '2020-05-10', 'average_visit_duration': 104.12611515656313},
#  {'date': '2020-05-11', 'average_visit_duration': 369.59419128407325},
#  {'date': '2020-05-12', 'average_visit_duration': 311.3876617987038},
#  {'date': '2020-05-13', 'average_visit_duration': 272.1560426089648},
#  {'date': '2020-05-14', 'average_visit_duration': 299.580965267243},
#  {'date': '2020-05-15', 'average_visit_duration': 138.305813552972},
#  {'date': '2020-05-16', 'average_visit_duration': 160.73517734930937},
#  {'date': '2020-05-17', 'average_visit_duration': 197.38954158428146},
#  {'date': '2020-05-18', 'average_visit_duration': 335.29485012075503},
#  {'date': '2020-05-19', 'average_visit_duration': 236.43616736430616},
#  {'date': '2020-05-20', 'average_visit_duration': 229.4043494590475},
#  {'date': '2020-05-21', 'average_visit_duration': 408.6694134062298},
#  {'date': '2020-05-22', 'average_visit_duration': 171.05674482152418},
#  {'date': '2020-05-23', 'average_visit_duration': 406.43661087767424},
#  {'date': '2020-05-24', 'average_visit_duration': 325.20848864280856},
#  {'date': '2020-05-25', 'average_visit_duration': 241.57194624260867},
#  {'date': '2020-05-26', 'average_visit_duration': 323.3732478152114},
#  {'date': '2020-05-27', 'average_visit_duration': 414.4740561370636},
#  {'date': '2020-05-28', 'average_visit_duration': 268.9498985393779},
#  {'date': '2020-05-29', 'average_visit_duration': 275.05842621000596},
#  {'date': '2020-05-30', 'average_visit_duration': 338.0081763727421},
#  {'date': '2020-05-31', 'average_visit_duration': 283.5993748504277},
#  {'date': '2020-06-01', 'average_visit_duration': 226.1794382533267},
#  {'date': '2020-06-02', 'average_visit_duration': 232.14049065263657},
#  {'date': '2020-06-03', 'average_visit_duration': 160.52879848713977},
#  {'date': '2020-06-04', 'average_visit_duration': 196.5405535933078},
#  {'date': '2020-06-05', 'average_visit_duration': 327.3435035166369},
#  {'date': '2020-06-06', 'average_visit_duration': 207.4654230318646},
#  {'date': '2020-06-07', 'average_visit_duration': 232.19776947267073},
#  {'date': '2020-06-08', 'average_visit_duration': 153.1011821612713},
#  {'date': '2020-06-09', 'average_visit_duration': 254.10094034939317},
#  {'date': '2020-06-10', 'average_visit_duration': 238.99140418231744},
#  {'date': '2020-06-11', 'average_visit_duration': 155.49811253874307},
#  {'date': '2020-06-12', 'average_visit_duration': 315.8944774901643},
#  {'date': '2020-06-13', 'average_visit_duration': 267.7344396447165},
#  {'date': '2020-06-14', 'average_visit_duration': 279.00061929996787},
#  {'date': '2020-06-15', 'average_visit_duration': 366.6115396041415},
#  {'date': '2020-06-16', 'average_visit_duration': 190.82370812868973},
#  {'date': '2020-06-17', 'average_visit_duration': 277.04554155238566},
#  {'date': '2020-06-18', 'average_visit_duration': 163.13496498083472},
#  {'date': '2020-06-19', 'average_visit_duration': 302.533612067396},
#  {'date': '2020-06-20', 'average_visit_duration': 191.77486480812166},
#  {'date': '2020-06-21', 'average_visit_duration': 159.952599193214},
#  {'date': '2020-06-22', 'average_visit_duration': 240.1453161824164},
#  {'date': '2020-06-23', 'average_visit_duration': 422.80145654789237},
#  {'date': '2020-06-24', 'average_visit_duration': 277.41872146714934},
#  {'date': '2020-06-25', 'average_visit_duration': 234.0622667422017},
#  {'date': '2020-06-26', 'average_visit_duration': 489.5796484023716},
#  {'date': '2020-06-27', 'average_visit_duration': 303.1801597571633},
#  {'date': '2020-06-28', 'average_visit_duration': 127.14327188032877},
#  {'date': '2020-06-29', 'average_visit_duration': 148.20080185138286},
#  {'date': '2020-06-30', 'average_visit_duration': 203.74088286757015},
#  {'date': '2020-07-01', 'average_visit_duration': 339.19621313850604},
#  {'date': '2020-07-02', 'average_visit_duration': 381.2490554889637},
#  {'date': '2020-07-03', 'average_visit_duration': 262.7453407964914},
#  {'date': '2020-07-04', 'average_visit_duration': 187.1316718429787},
#  {'date': '2020-07-05', 'average_visit_duration': 330.9764425391806},
#  {'date': '2020-07-06', 'average_visit_duration': 319.915657153445},
#  {'date': '2020-07-07', 'average_visit_duration': 467.2544777764314},
#  {'date': '2020-07-08', 'average_visit_duration': 215.1007860934496},
#  {'date': '2020-07-09', 'average_visit_duration': 236.5211027762906},
#  {'date': '2020-07-10', 'average_visit_duration': 285.88901012802916},
#  {'date': '2020-07-11', 'average_visit_duration': 189.10971237967323},
#  {'date': '2020-07-12', 'average_visit_duration': 264.4195608284457},
#  {'date': '2020-07-13', 'average_visit_duration': 379.0167680231425},
#  {'date': '2020-07-14', 'average_visit_duration': 310.85319837092777},
#  {'date': '2020-07-15', 'average_visit_duration': 246.77302139331147},
#  {'date': '2020-07-16', 'average_visit_duration': 261.27058337385546},
#  {'date': '2020-07-17', 'average_visit_duration': 124.9967480520631},
#  {'date': '2020-07-18', 'average_visit_duration': 77.00673720293422},
#  {'date': '2020-07-19', 'average_visit_duration': 150.93735492914254},
#  {'date': '2020-07-20', 'average_visit_duration': 237.37637997770466},
#  {'date': '2020-07-21', 'average_visit_duration': 327.38446169675024},
#  {'date': '2020-07-22', 'average_visit_duration': 224.43274688081036},
#  {'date': '2020-07-23', 'average_visit_duration': 163.3298719526907},
#  {'date': '2020-07-24', 'average_visit_duration': 232.01163079732567},
#  {'date': '2020-07-25', 'average_visit_duration': 104.46531584005298},
#  {'date': '2020-07-26', 'average_visit_duration': 190.76456108182953},
#  {'date': '2020-07-27', 'average_visit_duration': 244.00770820251435},
#  {'date': '2020-07-28', 'average_visit_duration': 343.9653062283015},
#  {'date': '2020-07-29', 'average_visit_duration': 306.8415190344883},
#  {'date': '2020-07-30', 'average_visit_duration': 233.7823281875764},
#  {'date': '2020-07-31', 'average_visit_duration': 378.44003000312523},
#  {'date': '2020-08-01', 'average_visit_duration': 205.7828156356211},
#  {'date': '2020-08-02', 'average_visit_duration': 200.80344604905324},
#  {'date': '2020-08-03', 'average_visit_duration': 207.2412558204767},
#  {'date': '2020-08-04', 'average_visit_duration': 57.852190148836655},
#  {'date': '2020-08-05', 'average_visit_duration': 139.13002169694366},
#  {'date': '2020-08-06', 'average_visit_duration': 213.58016727446514},
#  {'date': '2020-08-07', 'average_visit_duration': 400.18282496851833},
#  {'date': '2020-08-08', 'average_visit_duration': 557.880980839016},
#  {'date': '2020-08-09', 'average_visit_duration': 328.45870401956273},
#  {'date': '2020-08-10', 'average_visit_duration': 206.79864455359782},
#  {'date': '2020-08-11', 'average_visit_duration': 233.42618464943232},
#  {'date': '2020-08-12', 'average_visit_duration': 215.32133647176568},
#  {'date': '2020-08-13', 'average_visit_duration': 329.8224110795235},
#  {'date': '2020-08-14', 'average_visit_duration': 328.9583943659095},
#  {'date': '2020-08-15', 'average_visit_duration': 279.47991604005676},
#  {'date': '2020-08-16', 'average_visit_duration': 200.72921507424908},
#  {'date': '2020-08-17', 'average_visit_duration': 298.19280273760324},
#  {'date': '2020-08-18', 'average_visit_duration': 195.9760451373359},
#  {'date': '2020-08-19', 'average_visit_duration': 148.44331629364925},
#  {'date': '2020-08-20', 'average_visit_duration': 333.47313754364063},
#  {'date': '2020-08-21', 'average_visit_duration': 282.3179773532647},
#  {'date': '2020-08-22', 'average_visit_duration': 162.43527615233245},
#  {'date': '2020-08-23', 'average_visit_duration': 304.8171112007967},
#  {'date': '2020-08-24', 'average_visit_duration': 283.5384563915318},
#  {'date': '2020-08-25', 'average_visit_duration': 185.6390628764327},
#  {'date': '2020-08-26', 'average_visit_duration': 268.60408791333765},
#  {'date': '2020-08-27', 'average_visit_duration': 419.511031395194},
#  {'date': '2020-08-28', 'average_visit_duration': 298.5790642611639},
#  {'date': '2020-08-29', 'average_visit_duration': 135.48312851499531},
#  {'date': '2020-08-30', 'average_visit_duration': 176.11011018208396},
#  {'date': '2020-08-31', 'average_visit_duration': 212.56082770855048},
#  {'date': '2020-09-01', 'average_visit_duration': 174.18796259635715},
#  {'date': '2020-09-02', 'average_visit_duration': 163.7369660705892},
#  {'date': '2020-09-03', 'average_visit_duration': 175.27440591044362},
#  {'date': '2020-09-04', 'average_visit_duration': 134.45849316415206},
#  {'date': '2020-09-05', 'average_visit_duration': 138.54205270922017},
#  {'date': '2020-09-06', 'average_visit_duration': 338.6240836710505},
#  {'date': '2020-09-07', 'average_visit_duration': 260.06896173317944},
#  {'date': '2020-09-08', 'average_visit_duration': 313.41261365000065},
#  {'date': '2020-09-09', 'average_visit_duration': 199.52882342886753},
#  {'date': '2020-09-10', 'average_visit_duration': 217.68579592086837},
#  {'date': '2020-09-11', 'average_visit_duration': 170.1422412289193},
#  {'date': '2020-09-12', 'average_visit_duration': 240.20081846149043},
#  {'date': '2020-09-13', 'average_visit_duration': 216.1034570128917},
#  {'date': '2020-09-14', 'average_visit_duration': 278.3171340073332},
#  {'date': '2020-09-15', 'average_visit_duration': 300.95952927891693},
#  {'date': '2020-09-16', 'average_visit_duration': 440.12607057964516},
#  {'date': '2020-09-17', 'average_visit_duration': 292.738657146974},
#  {'date': '2020-09-18', 'average_visit_duration': 227.35751094895494},
#  {'date': '2020-09-19', 'average_visit_duration': 308.9296255382549},
#  {'date': '2020-09-20', 'average_visit_duration': 312.89136200054867},
#  {'date': '2020-09-21', 'average_visit_duration': 218.80611704674453},
#  {'date': '2020-09-22', 'average_visit_duration': 265.5447643201419},
#  {'date': '2020-09-23', 'average_visit_duration': 190.72803189755857},
#  {'date': '2020-09-24', 'average_visit_duration': 209.31534317521266},
#  {'date': '2020-09-25', 'average_visit_duration': 332.5928131559406},
#  {'date': '2020-09-26', 'average_visit_duration': 204.64366665786994},
#  {'date': '2020-09-27', 'average_visit_duration': 365.12662126210614},
#  {'date': '2020-09-28', 'average_visit_duration': 372.6678804947288},
#  {'date': '2020-09-29', 'average_visit_duration': 265.24854357770255},
#  {'date': '2020-09-30', 'average_visit_duration': 163.13447312664647},
#  {'date': '2020-10-01', 'average_visit_duration': 287.53953035215454},
#  {'date': '2020-10-02', 'average_visit_duration': 240.05983141330728},
#  {'date': '2020-10-03', 'average_visit_duration': 237.9214155384267},
#  {'date': '2020-10-04', 'average_visit_duration': 347.25827878002974},
#  {'date': '2020-10-05', 'average_visit_duration': 282.2960153718801},
#  {'date': '2020-10-06', 'average_visit_duration': 272.97184957029395},
#  {'date': '2020-10-07', 'average_visit_duration': 176.93313469356576},
#  {'date': '2020-10-08', 'average_visit_duration': 233.98429150957224},
#  {'date': '2020-10-09', 'average_visit_duration': 343.05349002697545},
#  {'date': '2020-10-10', 'average_visit_duration': 137.51959650903657},
#  {'date': '2020-10-11', 'average_visit_duration': 209.37051202526092},
#  {'date': '2020-10-12', 'average_visit_duration': 146.21450830245723},
#  {'date': '2020-10-13', 'average_visit_duration': 130.28228025080202},
#  {'date': '2020-10-14', 'average_visit_duration': 238.00120627884945},
#  {'date': '2020-10-15', 'average_visit_duration': 110.83958925257816},
#  {'date': '2020-10-16', 'average_visit_duration': 245.62146670513727},
#  {'date': '2020-10-17', 'average_visit_duration': 171.8020699047513},
#  {'date': '2020-10-18', 'average_visit_duration': 234.95969919802928},
#  {'date': '2020-10-19', 'average_visit_duration': 222.09329442982414},
#  {'date': '2020-10-20', 'average_visit_duration': 180.54349535454546},
#  {'date': '2020-10-21', 'average_visit_duration': 104.4575958733597},
#  {'date': '2020-10-22', 'average_visit_duration': 161.7161070983997},
#  {'date': '2020-10-23', 'average_visit_duration': 269.59193915422674},
#  {'date': '2020-10-24', 'average_visit_duration': 175.41304352130769},
#  {'date': '2020-10-25', 'average_visit_duration': 196.82620503751573},
#  {'date': '2020-10-26', 'average_visit_duration': 125.26290533806204},
#  {'date': '2020-10-27', 'average_visit_duration': 220.493022543748},
#  {'date': '2020-10-28', 'average_visit_duration': 200.45339600691605},
#  {'date': '2020-10-29', 'average_visit_duration': 199.44327243420668},
#  {'date': '2020-10-30', 'average_visit_duration': 452.3818838653696},
#  {'date': '2020-10-31', 'average_visit_duration': 188.32303827394503},
#  {'date': '2020-11-01', 'average_visit_duration': 116.63936384897131},
#  {'date': '2020-11-02', 'average_visit_duration': 182.20671792825829},
#  {'date': '2020-11-03', 'average_visit_duration': 210.1606991765172},
#  {'date': '2020-11-04', 'average_visit_duration': 212.67295557443558},
#  {'date': '2020-11-05', 'average_visit_duration': 126.667331981919},
#  {'date': '2020-11-06', 'average_visit_duration': 195.91135408680665},
#  {'date': '2020-11-07', 'average_visit_duration': 356.8700721471037},
#  {'date': '2020-11-08', 'average_visit_duration': 259.8594997094302},
#  {'date': '2020-11-09', 'average_visit_duration': 160.80193703873402},
#  {'date': '2020-11-10', 'average_visit_duration': 125.53109980270278},
#  {'date': '2020-11-11', 'average_visit_duration': 173.12207057961064},
#  {'date': '2020-11-12', 'average_visit_duration': 328.1762030448529},
#  {'date': '2020-11-13', 'average_visit_duration': 172.54050887791539},
#  {'date': '2020-11-14', 'average_visit_duration': 193.2369230611121},
#  {'date': '2020-11-15', 'average_visit_duration': 287.35648382561834},
#  {'date': '2020-11-16', 'average_visit_duration': 120.1879688397647},
#  {'date': '2020-11-17', 'average_visit_duration': 310.5592574880746},
#  {'date': '2020-11-18', 'average_visit_duration': 262.48012029498835},
#  {'date': '2020-11-19', 'average_visit_duration': 264.9636409875635},
#  {'date': '2020-11-20', 'average_visit_duration': 231.02959334254797},
#  {'date': '2020-11-21', 'average_visit_duration': 212.75760246937566},
#  {'date': '2020-11-22', 'average_visit_duration': 186.72723510036838},
#  {'date': '2020-11-23', 'average_visit_duration': 141.04074890675014},
#  {'date': '2020-11-24', 'average_visit_duration': 176.7067678003204},
#  {'date': '2020-11-25', 'average_visit_duration': 262.48012029498835},
#  {'date': '2020-11-26', 'average_visit_duration': 202.3320212910449},
#  {'date': '2020-11-27', 'average_visit_duration': 113.25542722137341},
#  {'date': '2020-11-28', 'average_visit_duration': 227.23687346458763},
#  {'date': '2020-11-29', 'average_visit_duration': 168.73299054526456},
#  {'date': '2020-11-30', 'average_visit_duration': 135.30501321698466},
#  {'date': '2020-12-01', 'average_visit_duration': 174.76556045968726},
#  {'date': '2020-12-02', 'average_visit_duration': 204.75719315421594},
#  {'date': '2020-12-03', 'average_visit_duration': 199.65825301195198},
#  {'date': '2020-12-04', 'average_visit_duration': 286.507702103509},
#  {'date': '2020-12-05', 'average_visit_duration': 201.16790959809256},
#  {'date': '2020-12-06', 'average_visit_duration': 237.28284857811056},
#  {'date': '2020-12-07', 'average_visit_duration': 260.2415818362336},
#  {'date': '2020-12-08', 'average_visit_duration': 173.1542228271693},
#  {'date': '2020-12-09', 'average_visit_duration': 265.3719896192889},
#  {'date': '2020-12-10', 'average_visit_duration': 95.77360190864928},
#  {'date': '2020-12-11', 'average_visit_duration': 254.04820277503092},
#  {'date': '2020-12-12', 'average_visit_duration': 218.34154679536707},
#  {'date': '2020-12-13', 'average_visit_duration': 118.82771194379427},
#  {'date': '2020-12-14', 'average_visit_duration': 241.3296627353904},
#  {'date': '2020-12-15', 'average_visit_duration': 297.5824364770643},
#  {'date': '2020-12-16', 'average_visit_duration': 178.2923333610655},
#  {'date': '2020-12-17', 'average_visit_duration': 311.89591517663723},
#  {'date': '2020-12-18', 'average_visit_duration': 296.8630887587323},
#  {'date': '2020-12-19', 'average_visit_duration': 291.27727321177576},
#  {'date': '2020-12-20', 'average_visit_duration': 263.83345222414914},
#  {'date': '2020-12-21', 'average_visit_duration': 256.0250595975558},
#  {'date': '2020-12-22', 'average_visit_duration': 203.19103877960143},
#  {'date': '2020-12-23', 'average_visit_duration': 278.9667763173284},
#  {'date': '2020-12-24', 'average_visit_duration': 290.71068051022036},
#  {'date': '2020-12-25', 'average_visit_duration': 324.139784560936},
#  {'date': '2020-12-26', 'average_visit_duration': 233.83124108086068},
#  {'date': '2020-12-27', 'average_visit_duration': 164.45011874365375},
#  {'date': '2020-12-28', 'average_visit_duration': 69.94635702031765},
#  {'date': '2020-12-29', 'average_visit_duration': 204.3571554353303},
#  {'date': '2020-12-30', 'average_visit_duration': 215.07670976967503},
#  {'date': '2020-12-31', 'average_visit_duration': 173.7847394366008},
#  {'date': '2021-01-01', 'average_visit_duration': 183.9627892674829},
#  {'date': '2021-01-02', 'average_visit_duration': 184.02403682404417},
#  {'date': '2021-01-03', 'average_visit_duration': 279.3462474870081},
#  {'date': '2021-01-04', 'average_visit_duration': 141.2893596912109},
#  {'date': '2021-01-05', 'average_visit_duration': 171.26597023371048},
#  {'date': '2021-01-06', 'average_visit_duration': 119.29884769878575},
#  {'date': '2021-01-07', 'average_visit_duration': 119.5709978788374},
#  {'date': '2021-01-08', 'average_visit_duration': 124.13229348824488},
#  {'date': '2021-01-09', 'average_visit_duration': 223.37322024770958},
#  {'date': '2021-01-10', 'average_visit_duration': 191.7928819084281},
#  {'date': '2021-01-11', 'average_visit_duration': 106.15550590831617},
#  {'date': '2021-01-12', 'average_visit_duration': 156.05869057481675},
#  {'date': '2021-01-13', 'average_visit_duration': 125.4191049500234},
#  {'date': '2021-01-14', 'average_visit_duration': 196.02769884651497},
#  {'date': '2021-01-15', 'average_visit_duration': 131.77053542455013},
#  {'date': '2021-01-16', 'average_visit_duration': 228.28782805461466},
#  {'date': '2021-01-17', 'average_visit_duration': 184.08325118203024},
#  {'date': '2021-01-18', 'average_visit_duration': 232.5499219255981},
#  {'date': '2021-01-19', 'average_visit_duration': 191.86308274026146},
#  {'date': '2021-01-20', 'average_visit_duration': 232.45249585326346},
#  {'date': '2021-01-21', 'average_visit_duration': 222.7176061641501},
#  {'date': '2021-01-22', 'average_visit_duration': 258.54762411335014},
#  {'date': '2021-01-23', 'average_visit_duration': 161.24279726606167},
#  {'date': '2021-01-24', 'average_visit_duration': 130.30541733372866},
#  {'date': '2021-01-25', 'average_visit_duration': 248.7079954904242},
#  {'date': '2021-01-26', 'average_visit_duration': 100.07267423268779},
#  {'date': '2021-01-27', 'average_visit_duration': 166.17035222597053},
#  {'date': '2021-01-28', 'average_visit_duration': 217.63573324946915},
#  {'date': '2021-01-29', 'average_visit_duration': 114.88543704528503},
#  {'date': '2021-01-30', 'average_visit_duration': 112.69222487161379},
#  {'date': '2021-01-31', 'average_visit_duration': 97.33750912676452},
#  {'date': '2021-02-01', 'average_visit_duration': 159.04537535058031},
#  {'date': '2021-02-02', 'average_visit_duration': 154.35921045381016},
#  {'date': '2021-02-03', 'average_visit_duration': 165.4980150888985},
#  {'date': '2021-02-04', 'average_visit_duration': 197.31929128590744},
#  {'date': '2021-02-05', 'average_visit_duration': 229.6968423860611},
#  {'date': '2021-02-06', 'average_visit_duration': 89.61475535400837},
#  {'date': '2021-02-07', 'average_visit_duration': 172.4440089121456},
#  {'date': '2021-02-08', 'average_visit_duration': 153.30780870675235},
#  {'date': '2021-02-09', 'average_visit_duration': 201.56102412683651},
#  {'date': '2021-02-10', 'average_visit_duration': 214.0999459783057},
#  {'date': '2021-02-11', 'average_visit_duration': 125.04298164510853},
#  {'date': '2021-02-12', 'average_visit_duration': 159.35548491850582},
#  {'date': '2021-02-13', 'average_visit_duration': 188.46827711863065},
#  {'date': '2021-02-14', 'average_visit_duration': 175.71394967607634},
#  {'date': '2021-02-15', 'average_visit_duration': 147.64537417794685},
#  {'date': '2021-02-16', 'average_visit_duration': 173.30833087569388},
#  {'date': '2021-02-17', 'average_visit_duration': 177.62523617000025},
#  {'date': '2021-02-18', 'average_visit_duration': 269.07056499160126},
#  {'date': '2021-02-19', 'average_visit_duration': 162.41090331938685},
#  {'date': '2021-02-20', 'average_visit_duration': 143.91886053486542},
#  {'date': '2021-02-21', 'average_visit_duration': 221.4845443956},
#  {'date': '2021-02-22', 'average_visit_duration': 168.68466553877025},
#  {'date': '2021-02-23', 'average_visit_duration': 236.07126348899206},
#  {'date': '2021-02-24', 'average_visit_duration': 416.1254594949071},
#  {'date': '2021-02-25', 'average_visit_duration': 330.16545663092586},
#  {'date': '2021-02-26', 'average_visit_duration': 332.2339178874902},
#  {'date': '2021-02-27', 'average_visit_duration': 226.45344236545102},
#  {'date': '2021-02-28', 'average_visit_duration': 140.86677414071474},
#  {'date': '2021-03-01', 'average_visit_duration': 175.08981340882482},
#  {'date': '2021-03-02', 'average_visit_duration': 201.85701586272714},
#  {'date': '2021-03-03', 'average_visit_duration': 129.9128674571931},
#  {'date': '2021-03-04', 'average_visit_duration': 152.4414740196862},
#  {'date': '2021-03-05', 'average_visit_duration': 120.60361723798998},
#  {'date': '2021-03-06', 'average_visit_duration': 177.70899289242053},
#  {'date': '2021-03-07', 'average_visit_duration': 139.0636559679937},
#  {'date': '2021-03-08', 'average_visit_duration': 149.65303155299918},
#  {'date': '2021-03-09', 'average_visit_duration': 157.00988644467657},
#  {'date': '2021-03-10', 'average_visit_duration': 229.80730271604554},
#  {'date': '2021-03-11', 'average_visit_duration': 201.3250063783532},
#  {'date': '2021-03-12', 'average_visit_duration': 217.03643334616777},
#  {'date': '2021-03-13', 'average_visit_duration': 174.845109619666},
#  {'date': '2021-03-14', 'average_visit_duration': 253.45132199988615},
#  {'date': '2021-03-15', 'average_visit_duration': 193.1547693862806},
#  {'date': '2021-03-16', 'average_visit_duration': 132.3648223669616},
#  {'date': '2021-03-17', 'average_visit_duration': 267.8334065649473},
#  {'date': '2021-03-18', 'average_visit_duration': 91.77052657648207},
#  {'date': '2021-03-19', 'average_visit_duration': 144.35392934258},
#  {'date': '2021-03-20', 'average_visit_duration': 261.94824388018543},
#  {'date': '2021-03-21', 'average_visit_duration': 173.76953256002938},
#  {'date': '2021-03-22', 'average_visit_duration': 285.4925090574525},
#  {'date': '2021-03-23', 'average_visit_duration': 93.23256827137757},
#  {'date': '2021-03-24', 'average_visit_duration': 132.11968528157786},
#  {'date': '2021-03-25', 'average_visit_duration': 161.75351943067838},
#  {'date': '2021-03-26', 'average_visit_duration': 253.97598109758198},
#  {'date': '2021-03-27', 'average_visit_duration': 369.88179213534966},
#  {'date': '2021-03-28', 'average_visit_duration': 183.9978812915296},
#  {'date': '2021-03-29', 'average_visit_duration': 214.10130432219287},
#  {'date': '2021-03-30', 'average_visit_duration': 231.6315010464784},
#  {'date': '2021-03-31', 'average_visit_duration': 326.22856341086754},
#  {'date': '2021-04-01', 'average_visit_duration': 248.185235939652},
#  {'date': '2021-04-02', 'average_visit_duration': 234.25369625020085},
#  {'date': '2021-04-03', 'average_visit_duration': 182.27877632356368},
#  {'date': '2021-04-04', 'average_visit_duration': 195.87342216569397},
#  {'date': '2021-04-05', 'average_visit_duration': 345.66521835830997},
#  {'date': '2021-04-06', 'average_visit_duration': 277.02034667288336},
#  {'date': '2021-04-07', 'average_visit_duration': 146.30755648966485},
#  {'date': '2021-04-08', 'average_visit_duration': 165.39183553017668},
#  {'date': '2021-04-09', 'average_visit_duration': 298.26004808129477},
#  {'date': '2021-04-10', 'average_visit_duration': 205.424920178821},
#  {'date': '2021-04-11', 'average_visit_duration': 126.59864547325884},
#  {'date': '2021-04-12', 'average_visit_duration': 242.68224511596097},
#  {'date': '2021-04-13', 'average_visit_duration': 196.76623429623444},
#  {'date': '2021-04-14', 'average_visit_duration': 263.56345578233174},
#  {'date': '2021-04-15', 'average_visit_duration': 207.54190769360946},
#  {'date': '2021-04-16', 'average_visit_duration': 145.54133031728222},
#  {'date': '2021-04-17', 'average_visit_duration': 239.50564054460756},
#  {'date': '2021-04-18', 'average_visit_duration': 161.96251313845548},
#  {'date': '2021-04-19', 'average_visit_duration': 123.67039631026816},
#  {'date': '2021-04-20', 'average_visit_duration': 219.2749983076448},
#  {'date': '2021-04-21', 'average_visit_duration': 360.4499928277868},
#  {'date': '2021-04-22', 'average_visit_duration': 147.54477646535545},
#  {'date': '2021-04-23', 'average_visit_duration': 189.7482935242498},
#  {'date': '2021-04-24', 'average_visit_duration': 249.8435481500711},
#  {'date': '2021-04-25', 'average_visit_duration': 293.454584268362},
#  {'date': '2021-04-26', 'average_visit_duration': 338.522578083925},
#  {'date': '2021-04-27', 'average_visit_duration': 205.49370806863675},
#  {'date': '2021-04-28', 'average_visit_duration': 198.88371919719867},
#  {'date': '2021-04-29', 'average_visit_duration': 314.9466310408465},
#  {'date': '2021-04-30', 'average_visit_duration': 156.67348230196345},
#  {'date': '2021-05-01', 'average_visit_duration': 276.9290588170926},
#  {'date': '2021-05-02', 'average_visit_duration': 285.7577123064471},
#  {'date': '2021-05-03', 'average_visit_duration': 125.52069758032094},
#  {'date': '2021-05-04', 'average_visit_duration': 162.22279668702893},
#  {'date': '2021-05-05', 'average_visit_duration': 169.81746372623962},
#  {'date': '2021-05-06', 'average_visit_duration': 243.6566882381571},
#  {'date': '2021-05-07', 'average_visit_duration': 383.99021004624296},
#  {'date': '2021-05-08', 'average_visit_duration': 224.36394568411689},
#  {'date': '2021-05-09', 'average_visit_duration': 199.29234151219597},
#  {'date': '2021-05-10', 'average_visit_duration': 281.6577705162198},
#  {'date': '2021-05-11', 'average_visit_duration': 257.4894514646388},
#  {'date': '2021-05-12', 'average_visit_duration': 208.56847444519616},
#  {'date': '2021-05-13', 'average_visit_duration': 260.87477459849333},
#  {'date': '2021-05-14', 'average_visit_duration': 227.00080961068304},
#  {'date': '2021-05-15', 'average_visit_duration': 343.3531205229491},
#  {'date': '2021-05-16', 'average_visit_duration': 312.67730815290196},
#  {'date': '2021-05-17', 'average_visit_duration': 280.02407629062134},
#  {'date': '2021-05-18', 'average_visit_duration': 133.42097884337758},
#  {'date': '2021-05-19', 'average_visit_duration': 141.3162748494772},
#  {'date': '2021-05-20', 'average_visit_duration': 325.76594094102126},
#  {'date': '2021-05-21', 'average_visit_duration': 160.39830150594113},
#  {'date': '2021-05-22', 'average_visit_duration': 199.73449169317135},
#  {'date': '2021-05-23', 'average_visit_duration': 120.45707659522068},
#  {'date': '2021-05-24', 'average_visit_duration': 243.326355059591},
#  {'date': '2021-05-25', 'average_visit_duration': 250.22005723068546},
#  {'date': '2021-05-26', 'average_visit_duration': 194.27907050309665},
#  {'date': '2021-05-27', 'average_visit_duration': 303.72649914805385},
#  {'date': '2021-05-28', 'average_visit_duration': 233.93701421005355},
#  {'date': '2021-05-29', 'average_visit_duration': 301.8676833722859},
#  {'date': '2021-05-30', 'average_visit_duration': 266.3729870011853},
#  {'date': '2021-05-31', 'average_visit_duration': 351.5055318136514},
#  {'date': '2021-06-01', 'average_visit_duration': 486.891530548966},
#  {'date': '2021-06-02', 'average_visit_duration': 222.58254884291375},
#  {'date': '2021-06-03', 'average_visit_duration': 180.21377443189562},
#  {'date': '2021-06-04', 'average_visit_duration': 383.63820615971014},
#  {'date': '2021-06-05', 'average_visit_duration': 291.5460673851433},
#  {'date': '2021-06-06', 'average_visit_duration': 265.70875134816725},
#  {'date': '2021-06-07', 'average_visit_duration': 236.50464139195486},
#  {'date': '2021-06-08', 'average_visit_duration': 228.59649051723636},
#  {'date': '2021-06-09', 'average_visit_duration': 338.84737409432626},
#  {'date': '2021-06-10', 'average_visit_duration': 282.3459510005072},
#  {'date': '2021-06-11', 'average_visit_duration': 261.0807299554127},
#  {'date': '2021-06-12', 'average_visit_duration': 475.3953557086338},
#  {'date': '2021-06-13', 'average_visit_duration': 321.22574148649875},
#  {'date': '2021-06-14', 'average_visit_duration': 199.83635025193544},
#  {'date': '2021-06-15', 'average_visit_duration': 233.6298762949176},
#  {'date': '2021-06-16', 'average_visit_duration': 327.06815212580904},
#  {'date': '2021-06-17', 'average_visit_duration': 253.22124560312037},
#  {'date': '2021-06-18', 'average_visit_duration': 242.3856058757561},
#  {'date': '2021-06-19', 'average_visit_duration': 419.22431392476625},
#  {'date': '2021-06-20', 'average_visit_duration': 297.4716139678969},
#  {'date': '2021-06-21', 'average_visit_duration': 247.8160092524402},
#  {'date': '2021-06-22', 'average_visit_duration': 583.9504221653565},
#  {'date': '2021-06-23', 'average_visit_duration': 329.859354936596},
#  {'date': '2021-06-24', 'average_visit_duration': 381.6912358016675},
#  {'date': '2021-06-25', 'average_visit_duration': 281.5357216836487},
#  {'date': '2021-06-26', 'average_visit_duration': 319.5632583938869},
#  {'date': '2021-06-27', 'average_visit_duration': 194.56012995624192},
#  {'date': '2021-06-28', 'average_visit_duration': 508.84508752219836},
#  {'date': '2021-06-29', 'average_visit_duration': 494.98508999698925},
#  {'date': '2021-06-30', 'average_visit_duration': 544.7423766940997},
#  {'date': '2021-07-01', 'average_visit_duration': 554.449456790728},
#  {'date': '2021-07-02', 'average_visit_duration': 428.9296165852462},
#  {'date': '2021-07-03', 'average_visit_duration': 227.774968653068},
#  {'date': '2021-07-04', 'average_visit_duration': 307.8844938079525},
#  {'date': '2021-07-05', 'average_visit_duration': 478.2424516991279},
#  {'date': '2021-07-06', 'average_visit_duration': 419.11146607504304},
#  {'date': '2021-07-07', 'average_visit_duration': 398.40211009005293},
#  {'date': '2021-07-08', 'average_visit_duration': 354.6629030694187},
#  {'date': '2021-07-09', 'average_visit_duration': 508.68392867060606},
#  {'date': '2021-07-10', 'average_visit_duration': 194.47298203603745},
#  {'date': '2021-07-11', 'average_visit_duration': 188.11033886615726},
#  {'date': '2021-07-12', 'average_visit_duration': 265.9086772575539},
#  {'date': '2021-07-13', 'average_visit_duration': 406.10754339050453},
#  {'date': '2021-07-14', 'average_visit_duration': 249.0632411816591},
#  {'date': '2021-07-15', 'average_visit_duration': 202.67583750631812},
#  {'date': '2021-07-16', 'average_visit_duration': 178.52945801318435},
#  {'date': '2021-07-17', 'average_visit_duration': 328.12635395344273},
#  {'date': '2021-07-18', 'average_visit_duration': 186.39181459470797},
#  {'date': '2021-07-19', 'average_visit_duration': 309.3525342428243},
#  {'date': '2021-07-20', 'average_visit_duration': 175.3954727006102},
#  {'date': '2021-07-21', 'average_visit_duration': 260.86379300663697},
#  {'date': '2021-07-22', 'average_visit_duration': 364.32623265793313},
#  {'date': '2021-07-23', 'average_visit_duration': 278.5589576258186},
#  {'date': '2021-07-24', 'average_visit_duration': 228.40754520848722},
#  {'date': '2021-07-25', 'average_visit_duration': 368.75546269260633},
#  {'date': '2021-07-26', 'average_visit_duration': 199.18155166534956},
#  {'date': '2021-07-27', 'average_visit_duration': 487.9778046089208},
#  {'date': '2021-07-28', 'average_visit_duration': 207.55046772020623},
#  {'date': '2021-07-29', 'average_visit_duration': 464.2087992366561},
#  {'date': '2021-07-30', 'average_visit_duration': 221.97415874690597},
#  {'date': '2021-07-31', 'average_visit_duration': 435.4012400780634},
#  {'date': '2021-08-01', 'average_visit_duration': 361.8032046733818},
#  {'date': '2021-08-02', 'average_visit_duration': 699.4031937016596},
#  {'date': '2021-08-03', 'average_visit_duration': 469.9261401084723},
#  {'date': '2021-08-04', 'average_visit_duration': 274.1202746577357},
#  {'date': '2021-08-05', 'average_visit_duration': 300.83488351076295},
#  {'date': '2021-08-06', 'average_visit_duration': 370.78626257213864},
#  {'date': '2021-08-07', 'average_visit_duration': 123.90475614771407},
#  {'date': '2021-08-08', 'average_visit_duration': 203.8079191449095},
#  {'date': '2021-08-09', 'average_visit_duration': 194.0211279050697},
#  {'date': '2021-08-10', 'average_visit_duration': 307.4337392062567},
# ...
#  {'date': '2021-11-12', 'average_visit_duration': 570.7759068908765},
#  {'date': '2021-11-13', 'average_visit_duration': 289.28199341388375},
#  {'date': '2021-11-14', 'average_visit_duration': 276.31216714802537},
#  {'date': '2021-11-15', 'average_visit_duration': 88.2782607431525},
#  {'date': '2021-11-16', 'average_visit_duration': 570.0411450442139},
#  {'date': '2021-11-17', 'average_visit_duration': 267.54220572598706},
#  {'date': '2021-11-18', 'average_visit_duration': 63.25867466318873},
#  {'date': '2021-11-19', 'average_visit_duration': 217.62790989932694},
#  {'date': '2021-11-20', 'average_visit_duration': 141.30623861682596},
#  {'date': '2021-11-21', 'average_visit_duration': 165.0231680391582},
#  {'date': '2021-11-22', 'average_visit_duration': 188.91966590725679},
#  {'date': '2021-11-23', 'average_visit_duration': 231.18441126031902},
#  {'date': '2021-11-24', 'average_visit_duration': 190.48343057008918},
#  {'date': '2021-11-25', 'average_visit_duration': 310.125488267993},
#  {'date': '2021-11-26', 'average_visit_duration': 193.98819801080288},
#  {'date': '2021-11-27', 'average_visit_duration': 268.619023428405},
#  {'date': '2021-11-28', 'average_visit_duration': 358.5918970599711},
#  {'date': '2021-11-29', 'average_visit_duration': 280.34132388655905},
#  {'date': '2021-11-30', 'average_visit_duration': 132.94382030211258},
#  {'date': '2021-12-01', 'average_visit_duration': 244.14227071628278},
#  {'date': '2021-12-02', 'average_visit_duration': 124.16703337678844},
#  {'date': '2021-12-03', 'average_visit_duration': 533.5401586073108},
#  {'date': '2021-12-04', 'average_visit_duration': 315.0730317685693},
#  {'date': '2021-12-05', 'average_visit_duration': 261.3488148094355},
#  {'date': '2021-12-06', 'average_visit_duration': 571.7931033257461},
#  {'date': '2021-12-07', 'average_visit_duration': 170.24881802976563},
#  {'date': '2021-12-08', 'average_visit_duration': 231.4893474658288},
#  {'date': '2021-12-09', 'average_visit_duration': 306.9888906165191},
#  {'date': '2021-12-10', 'average_visit_duration': 578.4143543141273},
#  {'date': '2021-12-11', 'average_visit_duration': 455.27884950155067},
#  {'date': '2021-12-12', 'average_visit_duration': 235.54216136055388},
#  {'date': '2021-12-13', 'average_visit_duration': 705.6732068020879},
#  {'date': '2021-12-14', 'average_visit_duration': 1044.8289326674583},
#  {'date': '2021-12-15', 'average_visit_duration': 496.1771589636473},
#  {'date': '2021-12-16', 'average_visit_duration': 86.74624297428657},
#  {'date': '2021-12-17', 'average_visit_duration': 247.85400686153972},
#  {'date': '2021-12-18', 'average_visit_duration': 197.79441206186593},
#  {'date': '2021-12-19', 'average_visit_duration': 398.8266657030555},
#  {'date': '2021-12-20', 'average_visit_duration': 316.8061570268158},
#  {'date': '2021-12-21', 'average_visit_duration': 269.5183200933316},
#  {'date': '2021-12-22', 'average_visit_duration': 190.9999826223085},
#  {'date': '2021-12-23', 'average_visit_duration': 524.8866013599333},
#  {'date': '2021-12-24', 'average_visit_duration': 728.9835863169664},
#  {'date': '2021-12-25', 'average_visit_duration': 352.07151150807044},
#  {'date': '2021-12-26', 'average_visit_duration': 330.7951998370495},
#  {'date': '2021-12-27', 'average_visit_duration': 654.9040436102493},
#  {'date': '2021-12-28', 'average_visit_duration': 117.90212802181102},
#  {'date': '2021-12-29', 'average_visit_duration': 353.10127943001925},
#  {'date': '2021-12-30', 'average_visit_duration': 410.72459643494017},
#  {'date': '2021-12-31', 'average_visit_duration': 232.61215399441429},
#  {'date': '2022-01-01', 'average_visit_duration': 284.3060225455699},
#  {'date': '2022-01-02', 'average_visit_duration': 381.7860938856449},
#  {'date': '2022-01-03', 'average_visit_duration': 601.086737295723},
#  {'date': '2022-01-04', 'average_visit_duration': 446.5579192407245},
#  {'date': '2022-01-05', 'average_visit_duration': 261.56304013696246},
#  {'date': '2022-01-06', 'average_visit_duration': 353.95759618763265},
#  {'date': '2022-01-07', 'average_visit_duration': 221.4884391853841},
#  {'date': '2022-01-08', 'average_visit_duration': 365.67402229283994},
#  {'date': '2022-01-09', 'average_visit_duration': 384.3256332375386},
#  {'date': '2022-01-10', 'average_visit_duration': 491.5442939011228},
#  {'date': '2022-01-11', 'average_visit_duration': 333.14901903954916},
#  {'date': '2022-01-12', 'average_visit_duration': 432.45558503212584},
#  {'date': '2022-01-13', 'average_visit_duration': 492.35108453570456},
#  {'date': '2022-01-14', 'average_visit_duration': 419.7100904072186},
#  {'date': '2022-01-15', 'average_visit_duration': 296.8009342361201},
#  {'date': '2022-01-16', 'average_visit_duration': 158.57872064084944},
#  {'date': '2022-01-17', 'average_visit_duration': 173.38123701057714},
#  {'date': '2022-01-18', 'average_visit_duration': 226.9827090784356},
#  {'date': '2022-01-19', 'average_visit_duration': 306.2043320021339},
#  {'date': '2022-01-20', 'average_visit_duration': 222.9019519071978},
#  {'date': '2022-01-21', 'average_visit_duration': 205.54169277418433},
#  {'date': '2022-01-22', 'average_visit_duration': 336.79975271866414},
#  {'date': '2022-01-23', 'average_visit_duration': 303.1365404960097},
#  {'date': '2022-01-24', 'average_visit_duration': 270.2676408661336},
#  {'date': '2022-01-25', 'average_visit_duration': 396.3711672825063},
#  {'date': '2022-01-26', 'average_visit_duration': 306.0699468010025},
#  {'date': '2022-01-27', 'average_visit_duration': 354.6521311551856},
#  {'date': '2022-01-28', 'average_visit_duration': 241.67183384187118},
#  {'date': '2022-01-29', 'average_visit_duration': 216.75422658942495},
#  {'date': '2022-01-30', 'average_visit_duration': 357.33844540707395},
#  {'date': '2022-01-31', 'average_visit_duration': 385.18269733574806},
#  {'date': '2022-02-01', 'average_visit_duration': 397.5950092050775},
#  {'date': '2022-02-02', 'average_visit_duration': 511.3784577254781},
#  {'date': '2022-02-03', 'average_visit_duration': 502.2689250812714},
#  {'date': '2022-02-04', 'average_visit_duration': 391.6298550952293},
#  {'date': '2022-02-05', 'average_visit_duration': 311.3510479563839},
#  {'date': '2022-02-06', 'average_visit_duration': 155.21347626751106},
#  {'date': '2022-02-07', 'average_visit_duration': 443.41212339608086},
#  {'date': '2022-02-08', 'average_visit_duration': 228.80570612270336},
#  {'date': '2022-02-09', 'average_visit_duration': 220.09910207249297},
#  {'date': '2022-02-10', 'average_visit_duration': 368.84513433623715},
#  {'date': '2022-02-11', 'average_visit_duration': 292.1231621479588},
#  {'date': '2022-02-12', 'average_visit_duration': 421.4710652976875},
#  {'date': '2022-02-13', 'average_visit_duration': 292.5367178007419},
#  {'date': '2022-02-14', 'average_visit_duration': 106.20389614739946},
#  {'date': '2022-02-15', 'average_visit_duration': 262.8403890369435},
#  {'date': '2022-02-16', 'average_visit_duration': 419.8719526330342},
#  {'date': '2022-02-17', 'average_visit_duration': 331.452526763939},
#  {'date': '2022-02-18', 'average_visit_duration': 176.1805808041905},
#  {'date': '2022-02-19', 'average_visit_duration': 133.63673491738845},
#  {'date': '2022-02-20', 'average_visit_duration': 164.48679681583442},
#  {'date': '2022-02-21', 'average_visit_duration': 77.01535609353627},
#  {'date': '2022-02-22', 'average_visit_duration': 580.9237885065885},
#  {'date': '2022-02-23', 'average_visit_duration': 275.60980250819114},
#  {'date': '2022-02-24', 'average_visit_duration': 366.9674595352693},
#  {'date': '2022-02-25', 'average_visit_duration': 360.29695315436396},
#  {'date': '2022-02-26', 'average_visit_duration': 459.7980238601506},
#  {'date': '2022-02-27', 'average_visit_duration': 430.40625419831105},
#  {'date': '2022-02-28', 'average_visit_duration': 239.25699110530894},
#  {'date': '2022-03-01', 'average_visit_duration': 298.1097594236503},
#  {'date': '2022-03-02', 'average_visit_duration': 266.5240807159768},
#  {'date': '2022-03-03', 'average_visit_duration': 292.75076898475163},
#  {'date': '2022-03-04', 'average_visit_duration': 631.3498183795856},
#  {'date': '2022-03-05', 'average_visit_duration': 362.6916472378831},
#  {'date': '2022-03-06', 'average_visit_duration': 193.94805970123574},
#  {'date': '2022-03-07', 'average_visit_duration': 438.3094976658227},
#  {'date': '2022-03-08', 'average_visit_duration': 236.15919166249532},
#  {'date': '2022-03-09', 'average_visit_duration': 364.3887258803477},
#  {'date': '2022-03-10', 'average_visit_duration': 262.1404425856436},
#  {'date': '2022-03-11', 'average_visit_duration': 454.6350529674012},
#  {'date': '2022-03-12', 'average_visit_duration': 246.9859913800037},
#  {'date': '2022-03-13', 'average_visit_duration': 190.12321622637677},
#  {'date': '2022-03-14', 'average_visit_duration': 305.7033325948589},
#  {'date': '2022-03-15', 'average_visit_duration': 141.77160285051272},
#  {'date': '2022-03-16', 'average_visit_duration': 266.9086967657626},
#  {'date': '2022-03-17', 'average_visit_duration': 181.08955499878712},
#  {'date': '2022-03-18', 'average_visit_duration': 498.03417280430983},
#  {'date': '2022-03-19', 'average_visit_duration': 357.59563184949485},
#  {'date': '2022-03-20', 'average_visit_duration': 635.6183217079664},
#  {'date': '2022-03-21', 'average_visit_duration': 400.7304244187879},
#  {'date': '2022-03-22', 'average_visit_duration': 759.0419793105364},
#  {'date': '2022-03-23', 'average_visit_duration': 478.5195010082376},
#  {'date': '2022-03-24', 'average_visit_duration': 845.312478234246},
#  {'date': '2022-03-25', 'average_visit_duration': 499.6527136508637},
#  {'date': '2022-03-26', 'average_visit_duration': 383.98012117011694},
#  {'date': '2022-03-27', 'average_visit_duration': 600.010837906501},
#  {'date': '2022-03-28', 'average_visit_duration': 390.5098015878188},
#  {'date': '2022-03-29', 'average_visit_duration': 559.7840287134497},
#  {'date': '2022-03-30', 'average_visit_duration': 221.34807400961128},
#  {'date': '2022-03-31', 'average_visit_duration': 310.65832113534015},
#  {'date': '2022-04-01', 'average_visit_duration': 304.7734600160166},
#  {'date': '2022-04-02', 'average_visit_duration': 386.3709067287979},
#  {'date': '2022-04-03', 'average_visit_duration': 428.1189380577691},
#  {'date': '2022-04-04', 'average_visit_duration': 278.34223972088125},
#  {'date': '2022-04-05', 'average_visit_duration': 398.87167141332446},
#  {'date': '2022-04-06', 'average_visit_duration': 467.1405825562207},
#  {'date': '2022-04-07', 'average_visit_duration': 441.28270893170503},
#  {'date': '2022-04-08', 'average_visit_duration': 547.8664479706524},
#  {'date': '2022-04-09', 'average_visit_duration': 460.3044904797755},
#  {'date': '2022-04-10', 'average_visit_duration': 346.5120828744842},
#  {'date': '2022-04-11', 'average_visit_duration': 408.751233703583},
#  {'date': '2022-04-12', 'average_visit_duration': 438.8365453994615},
#  {'date': '2022-04-13', 'average_visit_duration': 503.1551531075586},
#  {'date': '2022-04-14', 'average_visit_duration': 353.03670017030623},
#  {'date': '2022-04-15', 'average_visit_duration': 343.29237637378077},
#  {'date': '2022-04-16', 'average_visit_duration': 361.39863728217216},
#  {'date': '2022-04-17', 'average_visit_duration': 457.2088606285928},
#  {'date': '2022-04-18', 'average_visit_duration': 657.1580070960147},
#  {'date': '2022-04-19', 'average_visit_duration': 283.5339471569831},
#  {'date': '2022-04-20', 'average_visit_duration': 275.8210059583873},
#  {'date': '2022-04-21', 'average_visit_duration': 449.44880211664145},
#  {'date': '2022-04-22', 'average_visit_duration': 329.537688237732},
#  {'date': '2022-04-23', 'average_visit_duration': 475.2642122019127},
#  {'date': '2022-04-24', 'average_visit_duration': 345.5548778068115},
#  {'date': '2022-04-25', 'average_visit_duration': 556.0163196307615},
#  {'date': '2022-04-26', 'average_visit_duration': 357.97810939698087},
#  {'date': '2022-04-27', 'average_visit_duration': 628.0948152115292},
#  {'date': '2022-04-28', 'average_visit_duration': 243.85620586112682},
#  {'date': '2022-04-29', 'average_visit_duration': 492.13943406995173},
#  {'date': '2022-04-30', 'average_visit_duration': 362.14120138454837},
#  {'date': '2022-05-01', 'average_visit_duration': 474.35429175014053},
#  {'date': '2022-05-02', 'average_visit_duration': 318.61242000544775},
#  {'date': '2022-05-03', 'average_visit_duration': 240.7400259035046},
#  {'date': '2022-05-04', 'average_visit_duration': 611.2515008032705},
#  {'date': '2022-05-05', 'average_visit_duration': 521.1305700996328},
#  {'date': '2022-05-06', 'average_visit_duration': 420.16442928494234},
#  {'date': '2022-05-07', 'average_visit_duration': 394.04016974354386},
#  {'date': '2022-05-08', 'average_visit_duration': 399.01617140659386},
#  {'date': '2022-05-09', 'average_visit_duration': 447.2907425223907},
#  {'date': '2022-05-10', 'average_visit_duration': 441.661138954688},
#  {'date': '2022-05-11', 'average_visit_duration': 566.3954031611385},
#  {'date': '2022-05-12', 'average_visit_duration': 350.79291993668966},
#  {'date': '2022-05-13', 'average_visit_duration': 636.6126410791351},
#  {'date': '2022-05-14', 'average_visit_duration': 412.24515964148185},
#  {'date': '2022-05-15', 'average_visit_duration': 511.5629825968207},
#  {'date': '2022-05-16', 'average_visit_duration': 608.1940825347892},
#  {'date': '2022-05-17', 'average_visit_duration': 300.93239132582767},
#  {'date': '2022-05-18', 'average_visit_duration': 310.7780320080444},
#  {'date': '2022-05-19', 'average_visit_duration': 446.22502569113107},
#  {'date': '2022-05-20', 'average_visit_duration': 277.8740149382333},
#  {'date': '2022-05-21', 'average_visit_duration': 1111.3282152359457},
#  {'date': '2022-05-22', 'average_visit_duration': 508.08255716751506},
#  {'date': '2022-05-23', 'average_visit_duration': 192.47422153918964},
#  {'date': '2022-05-24', 'average_visit_duration': 657.9685040164583},
#  {'date': '2022-05-25', 'average_visit_duration': 889.7886688266203},
#  {'date': '2022-05-26', 'average_visit_duration': 502.83914734448723},
#  {'date': '2022-05-27', 'average_visit_duration': 490.54830848104666},
#  {'date': '2022-05-28', 'average_visit_duration': 1041.771075053536},
#  {'date': '2022-05-29', 'average_visit_duration': 585.3253500938462},
#  {'date': '2022-05-30', 'average_visit_duration': 277.7917943371229},
#  {'date': '2022-05-31', 'average_visit_duration': 368.5229293310288},
#  {'date': '2022-06-01', 'average_visit_duration': 380.4221155014952},
#  {'date': '2022-06-02', 'average_visit_duration': 425.33536793261516},
#  {'date': '2022-06-03', 'average_visit_duration': 461.4564520421329},
#  {'date': '2022-06-04', 'average_visit_duration': 525.6030902516787},
#  {'date': '2022-06-05', 'average_visit_duration': 171.56159140237332},
#  {'date': '2022-06-06', 'average_visit_duration': 473.2298577936092},
#  {'date': '2022-06-07', 'average_visit_duration': 129.48803468168148},
#  {'date': '2022-06-08', 'average_visit_duration': 866.4730207856342},
#  {'date': '2022-06-09', 'average_visit_duration': 464.17786515582895},
#  {'date': '2022-06-10', 'average_visit_duration': 404.1059618707315},
#  {'date': '2022-06-11', 'average_visit_duration': 665.0545521956379},
#  {'date': '2022-06-12', 'average_visit_duration': 281.06771196506713},
#  {'date': '2022-06-13', 'average_visit_duration': 458.57881986003696},
#  {'date': '2022-06-14', 'average_visit_duration': 466.71871322765935},
#  {'date': '2022-06-15', 'average_visit_duration': 502.64983674760487},
#  {'date': '2022-06-16', 'average_visit_duration': 119.32378531911178},
#  {'date': '2022-06-17', 'average_visit_duration': 213.74526462405413},
#  {'date': '2022-06-18', 'average_visit_duration': 231.68915582343973},
#  {'date': '2022-06-19', 'average_visit_duration': 238.83563789725545},
#  {'date': '2022-06-20', 'average_visit_duration': 154.009725263986},
#  {'date': '2022-06-21', 'average_visit_duration': 339.11739960192267},
#  {'date': '2022-06-22', 'average_visit_duration': 231.19200819510198},
#  {'date': '2022-06-23', 'average_visit_duration': 262.6174869590378},
#  {'date': '2022-06-24', 'average_visit_duration': 353.4657741539711},
#  {'date': '2022-06-25', 'average_visit_duration': 348.38585057344955},
#  {'date': '2022-06-26', 'average_visit_duration': 423.6218904226869},
#  ...]

# %%
access_key = '9095e89d0b5649b0a1a7d2bb9c2c5816'
granularity = 'daily'
t0_date = '2019-10'
t1_date = '2022-10'
domain = 'pinterest.fr'
country_code = 'us'

top_domains_path = f'https://api.similarweb.com/v1/website/$All/topsites/total?api_key={access_key}&start_date=2022-10&end_date=2022-10&country={country_code}&format=json&page=1'
top_websites_data = requests.get(top_domains_path).json()
top_websites_data_dicts = top_websites_data['top_sites']

# %%
top_websites_data_dicts
# Out:
# [{'rank': 1, 'domain': 'google.com'},
#  {'rank': 2, 'domain': 'youtube.com'},
#  {'rank': 3, 'domain': 'facebook.com'},
#  {'rank': 4, 'domain': 'amazon.com'},
#  {'rank': 5, 'domain': 'yahoo.com'},
#  {'rank': 6, 'domain': 'twitter.com'},
#  {'rank': 7, 'domain': 'wikipedia.org'},
#  {'rank': 8, 'domain': 'instagram.com'},
#  {'rank': 9, 'domain': 'reddit.com'},
#  {'rank': 10, 'domain': 'pornhub.com'},
#  {'rank': 11, 'domain': 'discord.com'},
#  {'rank': 12, 'domain': 'office.com'},
#  {'rank': 13, 'domain': 'xvideos.com'},
#  {'rank': 14, 'domain': 'espn.com'},
#  {'rank': 15, 'domain': 'xnxx.com'},
#  {'rank': 16, 'domain': 'ebay.com'},
#  {'rank': 17, 'domain': 'linkedin.com'},
#  {'rank': 18, 'domain': 'nytimes.com'},
#  {'rank': 19, 'domain': 'netflix.com'},
#  {'rank': 20, 'domain': 'microsoftonline.com'},
#  {'rank': 21, 'domain': 'instructure.com'},
#  {'rank': 22, 'domain': 'live.com'},
#  {'rank': 23, 'domain': 'cnn.com'},
#  {'rank': 24, 'domain': 'duckduckgo.com'},
#  {'rank': 25, 'domain': 'walmart.com'},
#  {'rank': 26, 'domain': 'bing.com'},
#  {'rank': 27, 'domain': 'msn.com'},
#  {'rank': 28, 'domain': 'quora.com'},
#  {'rank': 29, 'domain': 'pinterest.com'},
#  {'rank': 30, 'domain': 'zoom.us'},
#  {'rank': 31, 'domain': 'weather.com'},
#  {'rank': 32, 'domain': 'tiktok.com'},
#  {'rank': 33, 'domain': 'etsy.com'},
#  {'rank': 34, 'domain': 'zillow.com'},
#  {'rank': 35, 'domain': 'foxnews.com'},
#  {'rank': 36, 'domain': 'roblox.com'},
#  {'rank': 37, 'domain': 'fandom.com'},
#  {'rank': 38, 'domain': 'twitch.tv'},
#  {'rank': 39, 'domain': 'xhamster.com'},
#  {'rank': 40, 'domain': 'hulu.com'},
#  {'rank': 41, 'domain': 'indeed.com'},
#  {'rank': 42, 'domain': 'worldstar.com'},
#  {'rank': 43, 'domain': 'usps.com'},
#  {'rank': 44, 'domain': 'paypal.com'},
#  {'rank': 45, 'domain': 'accuweather.com'},
#  {'rank': 46, 'domain': 'sharepoint.com'},
#  {'rank': 47, 'domain': 'craigslist.org'},
#  {'rank': 48, 'domain': 'chaturbate.com'},
#  {'rank': 49, 'domain': 't-mobile.com'},
#  {'rank': 50, 'domain': 'imdb.com'},
#  {'rank': 51, 'domain': 'aol.com'},
#  {'rank': 52, 'domain': 'chase.com'},
#  {'rank': 53, 'domain': 'target.com'},
#  {'rank': 54, 'domain': 'archiveofourown.org'},
#  {'rank': 55, 'domain': 'microsoft.com'},
#  {'rank': 56, 'domain': 'homedepot.com'},
#  {'rank': 57, 'domain': 'nextdoor.com'},
#  {'rank': 58, 'domain': 'onlyfans.com'},
#  {'rank': 59, 'domain': 'att.com'},
#  {'rank': 60, 'domain': 'news.google.com'},
#  {'rank': 61, 'domain': 'washingtonpost.com'},
#  {'rank': 62, 'domain': 'spankbang.com'},
#  {'rank': 63, 'domain': 'ups.com'},
#  {'rank': 64, 'domain': 'finance.yahoo.com'},
#  {'rank': 65, 'domain': 'apple.com'},
#  {'rank': 66, 'domain': 'xfinity.com'},
#  {'rank': 67, 'domain': 'office365.com'},
#  {'rank': 68, 'domain': 'bbc.com'},
#  {'rank': 69, 'domain': 'spotify.com'},
#  {'rank': 70, 'domain': 'yelp.com'},
#  {'rank': 71, 'domain': 'quizlet.com'},
#  {'rank': 72, 'domain': 'fedex.com'},
#  {'rank': 73, 'domain': 'nypost.com'},
#  {'rank': 74, 'domain': 'realtor.com'},
#  {'rank': 75, 'domain': 'stripchat.com'},
#  {'rank': 76, 'domain': 'wellsfargo.com'},
#  {'rank': 77, 'domain': 'healthline.com'},
#  {'rank': 78, 'domain': 'cnbc.com'},
#  {'rank': 79, 'domain': 'att.net'},
#  {'rank': 80, 'domain': 'bankofamerica.com'},
#  {'rank': 81, 'domain': 'nih.gov'},
#  {'rank': 82, 'domain': 'dailymail.co.uk'},
#  {'rank': 83, 'domain': 'capitalone.com'},
#  {'rank': 84, 'domain': 'npr.org'},
#  {'rank': 85, 'domain': 'usatoday.com'},
#  {'rank': 86, 'domain': 'okta.com'},
#  {'rank': 87, 'domain': 'people.com'},
#  {'rank': 88, 'domain': 'bestbuy.com'},
#  {'rank': 89, 'domain': 'lowes.com'},
#  {'rank': 90, 'domain': 'samsung.com'},
#  {'rank': 91, 'domain': 'news.yahoo.com'},
#  {'rank': 92, 'domain': 'ticketmaster.com'},
#  {'rank': 93, 'domain': 'narvar.com'},
#  {'rank': 94, 'domain': 'lohiah.com'},
#  {'rank': 95, 'domain': 'hbomax.com'},
#  {'rank': 96, 'domain': 'tumblr.com'},
#  {'rank': 97, 'domain': 'sports.yahoo.com'},
#  {'rank': 98, 'domain': 'cbssports.com'},
#  {'rank': 99, 'domain': 'cvs.com'},
#  {'rank': 100, 'domain': 'wayfair.com'}]

# %%
selected_cohort = ['google', 'youtube', 'facebook', 'amazon', 'wikipedia', 'twitter', 'instagram', 'reddit', 'ebay', 'pinterest', 'tiktok', 'spotify']

final_websites_to_get = []

for prop_name in selected_cohort:
    property_web_sites = [d['domain'] for d in top_websites_data_dicts if prop_name in d['domain'] ]
    for d in property_web_sites:
        final_websites_to_get.append(d)
final_websites_to_get, len(final_websites_to_get)
# Out:
# (['google.com',
#   'google.co.uk',
#   'youtube.com',
#   'facebook.com',
#   'amazon.co.uk',
#   'amazon.com',
#   'wikipedia.org',
#   'twitter.com',
#   'instagram.com',
#   'reddit.com',
#   'ebay.co.uk',
#   'pinterest.co.uk',
#   'tiktok.com'],
#  13)
