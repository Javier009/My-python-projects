# %% [markdown]
# ### Phone Letter Combinations, level: expert
# https://edabit.com/challenge/xEGFoPmMm28h7HQ7a
#
# Given a string containing digits from 2-9 inclusive, return all possible letter combinations that the number could represent. A mapping of digit to letters (just like on the telephone buttons) is given below. Note that 1 does not map to any letters.
#
#
# Examples
# letter_combinations("23") ➞ ["ad", "ae", "af", "bd", "be", "bf", "cd", "ce", "cf"]
#
# letter_combinations("532") ➞ ["jda", "jdb", "jdc", "jea", "jeb", "jec", "jfa", "jfb", "jfc", "kda", "kdb", "kdc", "kea", "keb", "kec", "kfa", "kfb", "kfc", "lda", "ldb", "ldc", "lea", "leb", "lec", "lfa", "lfb", "lfc"]

# %%
from itertools import combinations

# %%
dict_phone = {'2': ['a','b','c'],
              '3': ['d','e','f'],
              '4': ['g','h','i'],
              '5': ['j','k','l'],
              '6': ['m','n','o'],
              '7': ['p','q','r','s'],
              '8': ['t','u','v'],
              '9': ['w','x','y','z']
             }

# %%
def phone_letters_comb(number):
    
    p_number = ''.join([n for n in str(number) if n in dict_phone])
    list_letters = []

    for num in p_number:

        if num in dict_phone:
            pre_list = [i for i in dict_phone[num]]
            for d in pre_list:
                list_letters.append(d)      
        else:
            pass
    list_letters = list(set(list_letters))
    result_list = [''.join(i) for i in combinations(list_letters, len(p_number))]
    return result_list

# %%
phone_letters_comb(56351907)
# Out:
# ['ljnmex',
#  'ljnmes',
#  'ljnmer',
#  'ljnmep',
#  'ljnmez',
#  'ljnmeo',
#  'ljnmef',
#  'ljnmek',
#  'ljnmeq',
#  'ljnmed',
#  'ljnmew',
#  'ljnmey',
#  'ljnmxs',
#  'ljnmxr',
#  'ljnmxp',
#  'ljnmxz',
#  'ljnmxo',
#  'ljnmxf',
#  'ljnmxk',
#  'ljnmxq',
#  'ljnmxd',
#  'ljnmxw',
#  'ljnmxy',
#  'ljnmsr',
#  'ljnmsp',
#  'ljnmsz',
#  'ljnmso',
#  'ljnmsf',
#  'ljnmsk',
#  'ljnmsq',
#  'ljnmsd',
#  'ljnmsw',
#  'ljnmsy',
#  'ljnmrp',
#  'ljnmrz',
#  'ljnmro',
#  'ljnmrf',
#  'ljnmrk',
#  'ljnmrq',
#  'ljnmrd',
#  'ljnmrw',
#  'ljnmry',
#  'ljnmpz',
#  'ljnmpo',
#  'ljnmpf',
#  'ljnmpk',
#  'ljnmpq',
#  'ljnmpd',
#  'ljnmpw',
#  'ljnmpy',
#  'ljnmzo',
#  'ljnmzf',
#  'ljnmzk',
#  'ljnmzq',
#  'ljnmzd',
#  'ljnmzw',
#  'ljnmzy',
#  'ljnmof',
#  'ljnmok',
#  'ljnmoq',
#  'ljnmod',
#  'ljnmow',
#  'ljnmoy',
#  'ljnmfk',
#  'ljnmfq',
#  'ljnmfd',
#  'ljnmfw',
#  'ljnmfy',
#  'ljnmkq',
#  'ljnmkd',
#  'ljnmkw',
#  'ljnmky',
#  'ljnmqd',
#  'ljnmqw',
#  'ljnmqy',
#  'ljnmdw',
# ...
